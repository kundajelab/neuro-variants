# %%
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

pd.options.display.max_rows = 200

# %%
model_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/chrombpnet_models/corces_2020/K562_bias'
outs_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/model_performance/corces_2020'

# %%
cell_type_metrics_dict = {'celltype': [], 'fold': [],
                          'peaks_pearsonr': [], 'peaks_spearmanr': [], 'peaks_median_jsd': [],
                          'bias_correction_status': [], 'tn5_footprint_1': [], 'tn5_footprint_2': [], 'tn5_footprint_3': [],
                          'tn5_footprint_4': [], 'tn5_footprint_5': []
                          }

for cluster in os.listdir(model_dir):
    print(cluster)

    # for fold in [os.listdir(os.path.join(model_dir, cluster))]:
    for fold in ['fold_' + str(i) for i in range(5)]:
        metrics_json = os.path.join(model_dir, cluster, fold, 'evaluation', 'chrombpnet_metrics.json')
        footprints_txt = os.path.join(model_dir, cluster, fold, 'evaluation', 'chrombpnet_nobias_max_bias_response.txt')

        # if os.path.isfile(metrics_json) and os.path.isfile(footprints_txt):
        metrics = json.load(open(metrics_json))
        cell_type_metrics_dict['celltype'].append(cluster.split('.')[1])
        cell_type_metrics_dict['fold'].append(fold)
        cell_type_metrics_dict['peaks_pearsonr'].append(metrics['counts_metrics']['peaks']['pearsonr'])
        cell_type_metrics_dict['peaks_spearmanr'].append(metrics['counts_metrics']['peaks']['spearmanr'])
        cell_type_metrics_dict['peaks_median_jsd'].append(metrics['profile_metrics']['peaks']['median_jsd'])
        
        with open(footprints_txt, 'r') as footprints_file:
            lines = footprints_file.readlines()[0]
            status = lines.split('_')[0] # corrected or uncorrected
            val1 = [float(lines.split('_')[1])]
            val_rest = [float(i) for i in lines.split('_')[2].split('/')]

            cell_type_metrics_dict['bias_correction_status'].append(status)
            cell_type_metrics_dict['tn5_footprint_1'].append(val_rest[0])
            cell_type_metrics_dict['tn5_footprint_2'].append(val_rest[1])
            cell_type_metrics_dict['tn5_footprint_3'].append(val_rest[2])
            cell_type_metrics_dict['tn5_footprint_4'].append(val_rest[3])
            cell_type_metrics_dict['tn5_footprint_5'].append(val_rest[4])

        # else:
        #     print()
        #     print(metrics_json)
        #     print(footprints_txt)
        #     print()
                    
cell_type_metrics_df = pd.DataFrame(cell_type_metrics_dict)
# Out:
# corces_2020.Cluster19
# corces_2020.Cluster10
# corces_2020.Cluster17
# corces_2020.Cluster12
# corces_2020.Cluster20
# corces_2020.Cluster8
# corces_2020.Cluster23
# corces_2020.Cluster6
# corces_2020.Cluster16
# corces_2020.Cluster18
# corces_2020.Cluster1
# corces_2020.Cluster24
# corces_2020.Cluster5
# corces_2020.Cluster15
# corces_2020.Cluster11
# corces_2020.Cluster9
# corces_2020.Cluster13
# corces_2020.Cluster21
# corces_2020.Cluster2
# corces_2020.Cluster4
# corces_2020.Cluster22
# corces_2020.Cluster14
# corces_2020.Cluster7
# corces_2020.Cluster3

# %%
cell_type_metrics_df
# Out:
#       celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 0    Cluster19  fold_0        0.604789         0.543208          0.530293
# 1    Cluster19  fold_1        0.595341         0.522744          0.528229
# 2    Cluster19  fold_2        0.626896         0.564088          0.531481
# 3    Cluster19  fold_3        0.613528         0.552922          0.530330
# 4    Cluster19  fold_4        0.602344         0.557733          0.531831
# 5    Cluster10  fold_0        0.704658         0.707058          0.675712
# 6    Cluster10  fold_1        0.680372         0.668546          0.679412
# 7    Cluster10  fold_2        0.724205         0.721450          0.677291
# 8    Cluster10  fold_3        0.704880         0.696603          0.681977
# 9    Cluster10  fold_4        0.659881         0.657033          0.681243
# 10   Cluster17  fold_0        0.756006         0.771294          0.755005
# 11   Cluster17  fold_1        0.750950         0.759744          0.761972
# 12   Cluster17  fold_2        0.762966         0.771519          0.761984
# 13   Cluster17  fold_3        0.735460         0.740377          0.760674
# 14   Cluster17  fold_4        0.759206         0.770774          0.753404
# 15   Cluster12  fold_0        0.758606         0.728570          0.643050
# 16   Cluster12  fold_1        0.748536         0.710324          0.644333
# 17   Cluster12  fold_2        0.747686         0.715649          0.641110
# 18   Cluster12  fold_3        0.742168         0.702798          0.643627
# 19   Cluster12  fold_4        0.747050         0.731072          0.636972
# 20   Cluster20  fold_0        0.609893         0.540886          0.443928
# 21   Cluster20  fold_1        0.583719         0.512020          0.444867
# 22   Cluster20  fold_2        0.591540         0.519801          0.443182
# 23   Cluster20  fold_3        0.590747         0.521285          0.444111
# 24   Cluster20  fold_4        0.622929         0.562847          0.443343
# 25    Cluster8  fold_0        0.795023         0.795546          0.716546
# 26    Cluster8  fold_1        0.787888         0.781195          0.720966
# 27    Cluster8  fold_2        0.791080         0.787801          0.718911
# 28    Cluster8  fold_3        0.787281         0.775244          0.722588
# 29    Cluster8  fold_4        0.786197         0.783471          0.713800
# 30   Cluster23  fold_0        0.650211         0.607779          0.600287
# 31   Cluster23  fold_1        0.634693         0.597028          0.601551
# 32   Cluster23  fold_2        0.650113         0.613691          0.602163
# 33   Cluster23  fold_3        0.642261         0.605535          0.600995
# 34   Cluster23  fold_4        0.636055         0.609535          0.603117
# 35    Cluster6  fold_0        0.816394         0.787193          0.687089
# 36    Cluster6  fold_1        0.796967         0.751407          0.691027
# 37    Cluster6  fold_2        0.813327         0.782737          0.688558
# 38    Cluster6  fold_3        0.803052         0.763631          0.691806
# 39    Cluster6  fold_4        0.795612         0.777514          0.684031
# 40   Cluster16  fold_0        0.682028         0.675706          0.643702
# 41   Cluster16  fold_1        0.697485         0.685530          0.648757
# 42   Cluster16  fold_2        0.690738         0.685143          0.643871
# 43   Cluster16  fold_3        0.669031         0.661897          0.646824
# 44   Cluster16  fold_4        0.688646         0.688855          0.638330
# 45   Cluster18  fold_0        0.793068         0.784235          0.718459
# 46   Cluster18  fold_1        0.772820         0.756303          0.718167
# 47   Cluster18  fold_2        0.795585         0.784039          0.726602
# 48   Cluster18  fold_3        0.781073         0.773311          0.723882
# 49   Cluster18  fold_4        0.765584         0.768316          0.711650
# 50    Cluster1  fold_0        0.687409         0.660991          0.364121
# 51    Cluster1  fold_1        0.646635         0.611252          0.367337
# 52    Cluster1  fold_2        0.682310         0.656681          0.362987
# 53    Cluster1  fold_3        0.656602         0.622054          0.365081
# 54    Cluster1  fold_4        0.682142         0.663855          0.365828
# 55   Cluster24  fold_0        0.648320         0.604993          0.507307
# 56   Cluster24  fold_1        0.649443         0.609207          0.510297
# 57   Cluster24  fold_2        0.650042         0.609260          0.511226
# 58   Cluster24  fold_3        0.646678         0.605554          0.507030
# 59   Cluster24  fold_4        0.647486         0.615618          0.502184
# 60    Cluster5  fold_0        0.793643         0.796639          0.686688
# 61    Cluster5  fold_1        0.793778         0.792543          0.690196
# 62    Cluster5  fold_2        0.784694         0.784037          0.688673
# 63    Cluster5  fold_3        0.779941         0.783394          0.689488
# 64    Cluster5  fold_4        0.762077         0.769708          0.684563
# 65   Cluster15  fold_0        0.643782         0.594622          0.496277
# 66   Cluster15  fold_1        0.640812         0.590583          0.503691
# 67   Cluster15  fold_2        0.648089         0.600962          0.498031
# 68   Cluster15  fold_3        0.615519         0.565053          0.501504
# 69   Cluster15  fold_4        0.641990         0.613226          0.496538
# 70   Cluster11  fold_0        0.762429         0.693640          0.505937
# 71   Cluster11  fold_1        0.730457         0.654130          0.506919
# 72   Cluster11  fold_2        0.751953         0.684807          0.505307
# 73   Cluster11  fold_3        0.734434         0.657501          0.506677
# 74   Cluster11  fold_4        0.747208         0.700871          0.498749
# 75    Cluster9  fold_0        0.684422         0.641459          0.544792
# 76    Cluster9  fold_1        0.668827         0.618985          0.548614
# 77    Cluster9  fold_2        0.676980         0.641758          0.544910
# 78    Cluster9  fold_3        0.663004         0.611010          0.548249
# 79    Cluster9  fold_4        0.675083         0.646083          0.539037
# 80   Cluster13  fold_0        0.756737         0.727498          0.653714
# 81   Cluster13  fold_1        0.754191         0.715935          0.658696
# 82   Cluster13  fold_2        0.766861         0.736334          0.656860
# 83   Cluster13  fold_3        0.742942         0.698248          0.657024
# 84   Cluster13  fold_4        0.763288         0.744943          0.651151
# 85   Cluster21  fold_0        0.560485         0.503003          0.420332
# 86   Cluster21  fold_1        0.551079         0.493443          0.418874
# 87   Cluster21  fold_2        0.581962         0.518116          0.419250
# 88   Cluster21  fold_3        0.561725         0.502669          0.420642
# 89   Cluster21  fold_4        0.609419         0.548801          0.416182
# 90    Cluster2  fold_0        0.610900         0.601646          0.373019
# 91    Cluster2  fold_1        0.623648         0.611083          0.375917
# 92    Cluster2  fold_2        0.630251         0.623418          0.374485
# 93    Cluster2  fold_3        0.598479         0.593031          0.375894
# 94    Cluster2  fold_4        0.641359         0.634117          0.376354
# 95    Cluster4  fold_0        0.641243         0.613772          0.552852
# 96    Cluster4  fold_1        0.616229         0.570437          0.556339
# 97    Cluster4  fold_2        0.632437         0.607029          0.550961
# 98    Cluster4  fold_3        0.635218         0.602058          0.552699
# 99    Cluster4  fold_4        0.649703         0.631229          0.556643
# 100  Cluster22  fold_0        0.607879         0.529886          0.438547
# 101  Cluster22  fold_1        0.603747         0.521058          0.439929
# 102  Cluster22  fold_2        0.612169         0.528174          0.440487
# 103  Cluster22  fold_3        0.579027         0.502735          0.441050
# 104  Cluster22  fold_4        0.634396         0.569862          0.438744
# 105  Cluster14  fold_0        0.706707         0.652417          0.557455
# 106  Cluster14  fold_1        0.694604         0.629823          0.558447
# 107  Cluster14  fold_2        0.702762         0.643327          0.557700
# 108  Cluster14  fold_3        0.688564         0.626369          0.556960
# 109  Cluster14  fold_4        0.699213         0.656787          0.554894
# 110   Cluster7  fold_0        0.737705         0.677886          0.618263
# 111   Cluster7  fold_1        0.753941         0.682250          0.620849
# 112   Cluster7  fold_2        0.757490         0.690463          0.616888
# 113   Cluster7  fold_3        0.746455         0.674749          0.620094
# 114   Cluster7  fold_4        0.753739         0.710201          0.612472
# 115   Cluster3  fold_0        0.688429         0.647159          0.573948
# 116   Cluster3  fold_1        0.694884         0.643678          0.577300
# 117   Cluster3  fold_2        0.692431         0.640265          0.572948
# 118   Cluster3  fold_3        0.674857         0.621192          0.573708
# 119   Cluster3  fold_4        0.684746         0.654966          0.572451
#
#     bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 0                corrected            0.001            0.001            0.001
# 1                corrected            0.001            0.001            0.001
# 2                corrected            0.001            0.001            0.001
# 3                corrected            0.001            0.001            0.001
# 4                corrected            0.001            0.001            0.001
# 5                corrected            0.001            0.001            0.001
# 6                corrected            0.001            0.001            0.001
# 7                corrected            0.001            0.001            0.001
# 8                corrected            0.001            0.001            0.001
# 9                corrected            0.001            0.001            0.001
# 10               corrected            0.001            0.001            0.001
# 11               corrected            0.001            0.001            0.001
# 12               corrected            0.001            0.001            0.001
# 13               corrected            0.001            0.001            0.001
# 14               corrected            0.001            0.001            0.001
# 15               corrected            0.001            0.001            0.001
# 16               corrected            0.001            0.001            0.001
# 17               corrected            0.001            0.001            0.001
# 18               corrected            0.001            0.001            0.001
# 19               corrected            0.001            0.001            0.001
# 20               corrected            0.001            0.001            0.001
# 21               corrected            0.001            0.001            0.001
# 22               corrected            0.001            0.001            0.001
# 23               corrected            0.001            0.001            0.001
# 24               corrected            0.001            0.001            0.001
# 25               corrected            0.001            0.001            0.001
# 26               corrected            0.001            0.001            0.001
# 27               corrected            0.001            0.001            0.001
# 28               corrected            0.001            0.001            0.001
# 29               corrected            0.001            0.001            0.001
# 30               corrected            0.001            0.001            0.001
# 31               corrected            0.001            0.001            0.001
# 32               corrected            0.001            0.001            0.001
# 33               corrected            0.001            0.001            0.001
# 34               corrected            0.001            0.001            0.001
# 35               corrected            0.001            0.001            0.001
# 36               corrected            0.001            0.001            0.001
# 37               corrected            0.001            0.001            0.001
# 38               corrected            0.001            0.001            0.001
# 39               corrected            0.001            0.001            0.001
# 40               corrected            0.001            0.001            0.001
# 41               corrected            0.001            0.001            0.001
# 42               corrected            0.001            0.001            0.001
# 43               corrected            0.001            0.001            0.001
# 44               corrected            0.001            0.001            0.001
# 45               corrected            0.001            0.001            0.001
# 46               corrected            0.001            0.001            0.001
# 47               corrected            0.001            0.001            0.001
# 48               corrected            0.001            0.001            0.001
# 49               corrected            0.001            0.001            0.001
# 50               corrected            0.001            0.001            0.001
# 51               corrected            0.001            0.001            0.001
# 52               corrected            0.001            0.001            0.001
# 53               corrected            0.001            0.001            0.001
# 54               corrected            0.001            0.001            0.001
# 55               corrected            0.001            0.001            0.001
# 56               corrected            0.001            0.001            0.001
# 57               corrected            0.001            0.001            0.001
# 58               corrected            0.001            0.001            0.001
# 59               corrected            0.001            0.001            0.001
# 60               corrected            0.001            0.001            0.001
# 61               corrected            0.001            0.001            0.001
# 62               corrected            0.001            0.001            0.001
# 63               corrected            0.001            0.001            0.001
# 64               corrected            0.001            0.001            0.001
# 65               corrected            0.001            0.001            0.001
# 66               corrected            0.001            0.001            0.001
# 67               corrected            0.001            0.001            0.001
# 68               corrected            0.001            0.001            0.001
# 69               corrected            0.001            0.001            0.001
# 70               corrected            0.001            0.001            0.001
# 71               corrected            0.001            0.001            0.001
# 72               corrected            0.001            0.001            0.001
# 73               corrected            0.001            0.001            0.001
# 74               corrected            0.001            0.001            0.001
# 75               corrected            0.001            0.001            0.001
# 76               corrected            0.001            0.001            0.001
# 77               corrected            0.001            0.001            0.001
# 78               corrected            0.001            0.001            0.001
# 79               corrected            0.001            0.001            0.001
# 80               corrected            0.001            0.001            0.001
# 81               corrected            0.001            0.001            0.001
# 82               corrected            0.001            0.001            0.001
# 83               corrected            0.001            0.001            0.001
# 84               corrected            0.001            0.001            0.001
# 85               corrected            0.001            0.001            0.001
# 86               corrected            0.001            0.001            0.001
# 87               corrected            0.001            0.001            0.001
# 88               corrected            0.001            0.001            0.001
# 89               corrected            0.001            0.001            0.001
# 90               corrected            0.001            0.001            0.001
# 91               corrected            0.001            0.001            0.001
# 92               corrected            0.001            0.001            0.001
# 93               corrected            0.001            0.001            0.001
# 94               corrected            0.001            0.001            0.001
# 95               corrected            0.001            0.001            0.001
# 96               corrected            0.001            0.001            0.001
# 97               corrected            0.001            0.001            0.001
# 98               corrected            0.001            0.001            0.001
# 99               corrected            0.001            0.001            0.001
# 100              corrected            0.001            0.001            0.001
# 101              corrected            0.001            0.001            0.001
# 102              corrected            0.001            0.001            0.001
# 103              corrected            0.001            0.001            0.001
# 104              corrected            0.001            0.001            0.001
# 105              corrected            0.001            0.001            0.001
# 106              corrected            0.001            0.001            0.001
# 107              corrected            0.001            0.001            0.001
# 108              corrected            0.001            0.001            0.001
# 109              corrected            0.001            0.001            0.001
# 110              corrected            0.001            0.001            0.001
# 111              corrected            0.001            0.001            0.001
# 112              corrected            0.001            0.001            0.001
# 113              corrected            0.001            0.001            0.001
# 114              corrected            0.001            0.001            0.001
# 115              corrected            0.001            0.001            0.001
# 116              corrected            0.001            0.001            0.001
# 117              corrected            0.001            0.001            0.001
# 118              corrected            0.001            0.001            0.001
# 119              corrected            0.001            0.001            0.001
#
#      tn5_footprint_4  tn5_footprint_5
# 0              0.001            0.001
# 1              0.001            0.001
# 2              0.001            0.001
# 3              0.002            0.001
# 4              0.001            0.001
# 5              0.001            0.001
# 6              0.001            0.001
# 7              0.001            0.001
# 8              0.001            0.001
# 9              0.001            0.001
# 10             0.001            0.001
# 11             0.001            0.001
# 12             0.001            0.001
# 13             0.001            0.001
# 14             0.001            0.001
# 15             0.001            0.001
# 16             0.001            0.001
# 17             0.001            0.001
# 18             0.002            0.001
# 19             0.002            0.001
# 20             0.001            0.001
# 21             0.001            0.001
# 22             0.001            0.001
# 23             0.002            0.001
# 24             0.001            0.001
# 25             0.001            0.001
# 26             0.001            0.001
# 27             0.001            0.001
# 28             0.001            0.001
# 29             0.001            0.001
# 30             0.001            0.001
# 31             0.001            0.001
# 32             0.001            0.001
# 33             0.001            0.001
# 34             0.002            0.001
# 35             0.001            0.001
# 36             0.001            0.001
# 37             0.001            0.001
# 38             0.001            0.001
# 39             0.001            0.001
# 40             0.001            0.001
# 41             0.001            0.001
# 42             0.001            0.001
# 43             0.001            0.001
# 44             0.001            0.001
# 45             0.001            0.001
# 46             0.001            0.001
# 47             0.002            0.001
# 48             0.001            0.001
# 49             0.001            0.001
# 50             0.002            0.001
# 51             0.002            0.001
# 52             0.002            0.001
# 53             0.001            0.001
# 54             0.001            0.001
# 55             0.001            0.001
# 56             0.001            0.001
# 57             0.001            0.001
# 58             0.001            0.001
# 59             0.001            0.001
# 60             0.001            0.001
# 61             0.001            0.001
# 62             0.001            0.001
# 63             0.001            0.001
# 64             0.001            0.001
# 65             0.001            0.001
# 66             0.001            0.001
# 67             0.001            0.001
# 68             0.001            0.001
# 69             0.001            0.001
# 70             0.002            0.001
# 71             0.001            0.001
# 72             0.001            0.001
# 73             0.001            0.001
# 74             0.001            0.001
# 75             0.001            0.001
# 76             0.001            0.001
# 77             0.001            0.001
# 78             0.001            0.001
# 79             0.001            0.001
# 80             0.002            0.001
# 81             0.001            0.001
# 82             0.001            0.001
# 83             0.001            0.001
# 84             0.001            0.001
# 85             0.001            0.001
# 86             0.001            0.001
# 87             0.001            0.001
# 88             0.001            0.001
# 89             0.002            0.001
# 90             0.001            0.001
# 91             0.001            0.001
# 92             0.001            0.001
# 93             0.002            0.001
# 94             0.002            0.001
# 95             0.001            0.001
# 96             0.001            0.001
# 97             0.001            0.001
# 98             0.001            0.001
# 99             0.001            0.001
# 100            0.001            0.001
# 101            0.001            0.001
# 102            0.001            0.001
# 103            0.001            0.001
# 104            0.001            0.001
# 105            0.001            0.001
# 106            0.001            0.001
# 107            0.001            0.001
# 108            0.001            0.001
# 109            0.001            0.001
# 110            0.001            0.001
# 111            0.001            0.001
# 112            0.002            0.001
# 113            0.001            0.001
# 114            0.001            0.001
# 115            0.001            0.001
# 116            0.001            0.001
# 117            0.001            0.001
# 118            0.001            0.001
# 119            0.001            0.001

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['bias_correction_status'] != 'corrected']
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df['tn5_footprint_1'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df['tn5_footprint_2'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df['tn5_footprint_3'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df['tn5_footprint_4'].max()
# Out:
# 0.002

# %%
cell_type_metrics_df['tn5_footprint_5'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_1'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_2'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_3'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_4'] > 0.001]
# Out:
#       celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 3    Cluster19  fold_3        0.613528         0.552922          0.530330
# 18   Cluster12  fold_3        0.742168         0.702798          0.643627
# 19   Cluster12  fold_4        0.747050         0.731072          0.636972
# 23   Cluster20  fold_3        0.590747         0.521285          0.444111
# 34   Cluster23  fold_4        0.636055         0.609535          0.603117
# 47   Cluster18  fold_2        0.795585         0.784039          0.726602
# 50    Cluster1  fold_0        0.687409         0.660991          0.364121
# 51    Cluster1  fold_1        0.646635         0.611252          0.367337
# 52    Cluster1  fold_2        0.682310         0.656681          0.362987
# 70   Cluster11  fold_0        0.762429         0.693640          0.505937
# 80   Cluster13  fold_0        0.756737         0.727498          0.653714
# 89   Cluster21  fold_4        0.609419         0.548801          0.416182
# 93    Cluster2  fold_3        0.598479         0.593031          0.375894
# 94    Cluster2  fold_4        0.641359         0.634117          0.376354
# 112   Cluster7  fold_2        0.757490         0.690463          0.616888
#
#     bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 3                corrected            0.001            0.001            0.001
# 18               corrected            0.001            0.001            0.001
# 19               corrected            0.001            0.001            0.001
# 23               corrected            0.001            0.001            0.001
# 34               corrected            0.001            0.001            0.001
# 47               corrected            0.001            0.001            0.001
# 50               corrected            0.001            0.001            0.001
# 51               corrected            0.001            0.001            0.001
# 52               corrected            0.001            0.001            0.001
# 70               corrected            0.001            0.001            0.001
# 80               corrected            0.001            0.001            0.001
# 89               corrected            0.001            0.001            0.001
# 93               corrected            0.001            0.001            0.001
# 94               corrected            0.001            0.001            0.001
# 112              corrected            0.001            0.001            0.001
#
#      tn5_footprint_4  tn5_footprint_5
# 3              0.002            0.001
# 18             0.002            0.001
# 19             0.002            0.001
# 23             0.002            0.001
# 34             0.002            0.001
# 47             0.002            0.001
# 50             0.002            0.001
# 51             0.002            0.001
# 52             0.002            0.001
# 70             0.002            0.001
# 80             0.002            0.001
# 89             0.002            0.001
# 93             0.002            0.001
# 94             0.002            0.001
# 112            0.002            0.001

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_5'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
median_peaks_pearson_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_pearsonr'].median().reset_index()
sorted_peaks_pearson_scores_by_celltype = median_peaks_pearson_scores_by_celltype.sort_values('peaks_pearsonr', ascending=False)['celltype']

median_peaks_spearman_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_spearmanr'].median().reset_index()
sorted_peaks_spearman_scores_by_celltype = median_peaks_spearman_scores_by_celltype.sort_values('peaks_spearmanr', ascending=False)['celltype']

median_peaks_jsd_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_median_jsd'].median().reset_index()
sorted_peaks_jsd_scores_by_celltype = median_peaks_jsd_scores_by_celltype.sort_values('peaks_median_jsd', ascending=False)['celltype']

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_pearsonr', data=cell_type_metrics_df, order=sorted_peaks_pearson_scores_by_celltype)
plt.title('Distribution of Pearson Correlation Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('Pearson Correlation', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
# plt.ylim(0.60, 0.90)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_spearmanr', data=cell_type_metrics_df, order=sorted_peaks_spearman_scores_by_celltype)
plt.title('Distribution of Spearman Correlation Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('Pearson Correlation', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
# plt.ylim(0.60, 0.90)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_median_jsd', data=cell_type_metrics_df, order=sorted_peaks_jsd_scores_by_celltype)
plt.title('Distribution of JSD Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('JSD', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
cell_type_metrics_df.to_csv(os.path.join(outs_dir, 'model_performance.tsv'),
                            index=False, sep='\t')
