# %%
import pandas as pd
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

pd.options.display.max_rows = 200

# %%
model_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/chrombpnet_models/trevino_2021/K562_bias'
outs_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/model_performance/trevino_2021'

# %%
cell_type_metrics_dict = {'celltype': [], 'fold': [],
                          'peaks_pearsonr': [], 'peaks_spearmanr': [], 'peaks_median_jsd': [],
                          'bias_correction_status': [], 'tn5_footprint_1': [], 'tn5_footprint_2': [], 'tn5_footprint_3': [],
                          'tn5_footprint_4': [], 'tn5_footprint_5': []
                          }

for cluster in os.listdir(model_dir):
    print(cluster)

    # for fold in [os.listdir(os.path.join(model_dir, cluster))]:
    for fold in ['fold_' + str(i) for i in range(5)]:
        metrics_json = os.path.join(model_dir, cluster, fold, 'evaluation', 'chrombpnet_metrics.json')
        footprints_txt = os.path.join(model_dir, cluster, fold, 'evaluation', 'chrombpnet_nobias_max_bias_response.txt')

        # if os.path.isfile(metrics_json) and os.path.isfile(footprints_txt):
        metrics = json.load(open(metrics_json))
        cell_type_metrics_dict['celltype'].append(cluster.split('.')[1])
        cell_type_metrics_dict['fold'].append(fold)
        cell_type_metrics_dict['peaks_pearsonr'].append(metrics['counts_metrics']['peaks']['pearsonr'])
        cell_type_metrics_dict['peaks_spearmanr'].append(metrics['counts_metrics']['peaks']['spearmanr'])
        cell_type_metrics_dict['peaks_median_jsd'].append(metrics['profile_metrics']['peaks']['median_jsd'])
        
        with open(footprints_txt, 'r') as footprints_file:
            lines = footprints_file.readlines()[0]
            status = lines.split('_')[0] # corrected or uncorrected
            val1 = [float(lines.split('_')[1])]
            val_rest = [float(i) for i in lines.split('_')[2].split('/')]

            cell_type_metrics_dict['bias_correction_status'].append(status)
            cell_type_metrics_dict['tn5_footprint_1'].append(val_rest[0])
            cell_type_metrics_dict['tn5_footprint_2'].append(val_rest[1])
            cell_type_metrics_dict['tn5_footprint_3'].append(val_rest[2])
            cell_type_metrics_dict['tn5_footprint_4'].append(val_rest[3])
            cell_type_metrics_dict['tn5_footprint_5'].append(val_rest[4])

        # else:
        #     print()
        #     print(metrics_json)
        #     print(footprints_txt)
        #     print()
                    
cell_type_metrics_df = pd.DataFrame(cell_type_metrics_dict)
# Out:
# trevino_2021.c5
# trevino_2021.c9
# trevino_2021.c19
# trevino_2021.c1
# trevino_2021.c10
# trevino_2021.c18
# trevino_2021.c16
# trevino_2021.c11
# trevino_2021.c13
# trevino_2021.c4
# trevino_2021.c7
# trevino_2021.c12
# trevino_2021.c20
# trevino_2021.c21
# trevino_2021.c0
# trevino_2021.c14
# trevino_2021.c3
# trevino_2021.c6
# trevino_2021.c2
# trevino_2021.c15
# trevino_2021.c8
# trevino_2021.c17

# %%
cell_type_metrics_df
# Out:
#     celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 0         c5  fold_0        0.702857         0.673040          0.595972
# 1         c5  fold_1        0.679659         0.637248          0.605662
# 2         c5  fold_2        0.689195         0.655785          0.598982
# 3         c5  fold_3        0.680604         0.641443          0.603978
# 4         c5  fold_4        0.696520         0.674770          0.594759
# 5         c9  fold_0        0.671511         0.647143          0.577507
# 6         c9  fold_1        0.665439         0.640120          0.583305
# 7         c9  fold_2        0.680925         0.657742          0.582628
# 8         c9  fold_3        0.654649         0.630529          0.583332
# 9         c9  fold_4        0.687129         0.674147          0.571656
# 10       c19  fold_0        0.707545         0.686258          0.652639
# 11       c19  fold_1        0.703236         0.686462          0.655584
# 12       c19  fold_2        0.703664         0.692056          0.651784
# 13       c19  fold_3        0.696430         0.675767          0.655086
# 14       c19  fold_4        0.705225         0.699156          0.645390
# 15        c1  fold_0        0.669629         0.640516          0.496284
# 16        c1  fold_1        0.659004         0.623300          0.502865
# 17        c1  fold_2        0.666086         0.640646          0.496808
# 18        c1  fold_3        0.663076         0.626099          0.504433
# 19        c1  fold_4        0.688853         0.668975          0.490317
# 20       c10  fold_0        0.686750         0.672343          0.627354
# 21       c10  fold_1        0.687562         0.670253          0.632722
# 22       c10  fold_2        0.663198         0.654270          0.632961
# 23       c10  fold_3        0.674153         0.658884          0.636616
# 24       c10  fold_4        0.695245         0.688724          0.622664
# 25       c18  fold_0        0.750766         0.730557          0.648864
# 26       c18  fold_1        0.755083         0.720627          0.654473
# 27       c18  fold_2        0.733188         0.708140          0.650278
# 28       c18  fold_3        0.731667         0.700721          0.652738
# 29       c18  fold_4        0.757896         0.740481          0.643482
# 30       c16  fold_0        0.787587         0.768414          0.649774
# 31       c16  fold_1        0.769088         0.738404          0.659915
# 32       c16  fold_2        0.772401         0.746665          0.654234
# 33       c16  fold_3        0.773122         0.741677          0.657532
# 34       c16  fold_4        0.791260         0.781399          0.638137
# 35       c11  fold_0        0.701683         0.672012          0.523228
# 36       c11  fold_1        0.681111         0.652749          0.532032
# 37       c11  fold_2        0.691045         0.671463          0.527209
# 38       c11  fold_3        0.665222         0.635262          0.533395
# 39       c11  fold_4        0.705518         0.689871          0.515512
# 40       c13  fold_0        0.666988         0.644690          0.536565
# 41       c13  fold_1        0.670532         0.640761          0.543449
# 42       c13  fold_2        0.675417         0.648178          0.537690
# 43       c13  fold_3        0.662794         0.640616          0.541731
# 44       c13  fold_4        0.685169         0.669040          0.525624
# 45        c4  fold_0        0.711133         0.696533          0.493059
# 46        c4  fold_1        0.703008         0.677061          0.503001
# 47        c4  fold_2        0.690396         0.671248          0.496156
# 48        c4  fold_3        0.699986         0.674046          0.508382
# 49        c4  fold_4        0.721491         0.715863          0.487959
# 50        c7  fold_0        0.694218         0.656163          0.466474
# 51        c7  fold_1        0.690794         0.652326          0.472376
# 52        c7  fold_2        0.691400         0.652158          0.463551
# 53        c7  fold_3        0.691812         0.644999          0.472952
# 54        c7  fold_4        0.706922         0.678198          0.459667
# 55       c12  fold_0        0.760876         0.745487          0.629813
# 56       c12  fold_1        0.764293         0.743010          0.638647
# 57       c12  fold_2        0.762825         0.747807          0.631058
# 58       c12  fold_3        0.735726         0.706437          0.636805
# 59       c12  fold_4        0.767206         0.759604          0.619714
# 60       c20  fold_0        0.766324         0.742585          0.667740
# 61       c20  fold_1        0.756357         0.726252          0.671594
# 62       c20  fold_2        0.758954         0.736321          0.665998
# 63       c20  fold_3        0.744919         0.715017          0.674314
# 64       c20  fold_4        0.742600         0.729416          0.663141
# 65       c21  fold_0        0.706822         0.704600          0.705935
# 66       c21  fold_1        0.671193         0.669406          0.708046
# 67       c21  fold_2        0.714267         0.708146          0.710446
# 68       c21  fold_3        0.674735         0.664396          0.711112
# 69       c21  fold_4        0.714535         0.713812          0.702006
# 70        c0  fold_0        0.680146         0.648529          0.513716
# 71        c0  fold_1        0.648227         0.603899          0.517505
# 72        c0  fold_2        0.668123         0.638471          0.508464
# 73        c0  fold_3        0.652977         0.617702          0.522239
# 74        c0  fold_4        0.684001         0.662980          0.504510
# 75       c14  fold_0        0.652710         0.632332          0.554858
# 76       c14  fold_1        0.650302         0.618850          0.562103
# 77       c14  fold_2        0.676421         0.661276          0.558060
# 78       c14  fold_3        0.639049         0.617020          0.560992
# 79       c14  fold_4        0.686326         0.671393          0.553336
# 80        c3  fold_0        0.694649         0.666917          0.498217
# 81        c3  fold_1        0.698279         0.665118          0.507718
# 82        c3  fold_2        0.695923         0.670654          0.499548
# 83        c3  fold_3        0.679873         0.646803          0.507098
# 84        c3  fold_4        0.712863         0.697346          0.491865
# 85        c6  fold_0        0.709739         0.672663          0.483804
# 86        c6  fold_1        0.689449         0.651861          0.487854
# 87        c6  fold_2        0.695545         0.662458          0.481425
# 88        c6  fold_3        0.674325         0.632529          0.493636
# 89        c6  fold_4        0.709557         0.683028          0.477948
# 90        c2  fold_0        0.653695         0.632327          0.565284
# 91        c2  fold_1        0.641631         0.613063          0.573895
# 92        c2  fold_2        0.657672         0.640282          0.563409
# 93        c2  fold_3        0.640429         0.620790          0.574198
# 94        c2  fold_4        0.669459         0.662512          0.563144
# 95       c15  fold_0        0.696388         0.694603          0.646583
# 96       c15  fold_1        0.700315         0.694514          0.648157
# 97       c15  fold_2        0.656719         0.655296          0.646379
# 98       c15  fold_3        0.689370         0.687954          0.650106
# 99       c15  fold_4        0.701134         0.700381          0.642462
# 100       c8  fold_0        0.681278         0.644742          0.528692
# 101       c8  fold_1        0.673661         0.636476          0.536414
# 102       c8  fold_2        0.684297         0.653117          0.526448
# 103       c8  fold_3        0.668413         0.632225          0.537546
# 104       c8  fold_4        0.706363         0.682938          0.523294
# 105      c17  fold_0        0.696411         0.675163          0.674148
# 106      c17  fold_1        0.680519         0.653481          0.675291
# 107      c17  fold_2        0.697383         0.671830          0.676839
# 108      c17  fold_3        0.672759         0.644242          0.677459
# 109      c17  fold_4        0.690401         0.682557          0.668665
#
#     bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 0                corrected            0.001            0.002            0.001
# 1                corrected            0.001            0.001            0.001
# 2                corrected            0.001            0.001            0.001
# 3                corrected            0.001            0.001            0.001
# 4                corrected            0.001            0.001            0.001
# 5                corrected            0.001            0.001            0.001
# 6                corrected            0.001            0.001            0.001
# 7                corrected            0.001            0.001            0.001
# 8                corrected            0.001            0.001            0.001
# 9                corrected            0.001            0.001            0.001
# 10               corrected            0.001            0.001            0.001
# 11               corrected            0.001            0.001            0.001
# 12               corrected            0.001            0.001            0.001
# 13               corrected            0.001            0.001            0.001
# 14               corrected            0.001            0.001            0.001
# 15               corrected            0.001            0.001            0.001
# 16               corrected            0.001            0.001            0.001
# 17               corrected            0.001            0.001            0.001
# 18               corrected            0.001            0.001            0.001
# 19               corrected            0.001            0.001            0.001
# 20               corrected            0.001            0.001            0.001
# 21               corrected            0.001            0.001            0.001
# 22               corrected            0.001            0.001            0.001
# 23               corrected            0.001            0.001            0.001
# 24               corrected            0.001            0.001            0.001
# 25               corrected            0.001            0.001            0.001
# 26               corrected            0.001            0.001            0.001
# 27               corrected            0.001            0.001            0.001
# 28               corrected            0.001            0.001            0.001
# 29               corrected            0.001            0.001            0.001
# 30               corrected            0.001            0.001            0.001
# 31               corrected            0.001            0.001            0.001
# 32               corrected            0.001            0.001            0.001
# 33               corrected            0.001            0.001            0.001
# 34               corrected            0.001            0.001            0.001
# 35               corrected            0.001            0.001            0.001
# 36               corrected            0.001            0.001            0.001
# 37               corrected            0.001            0.001            0.001
# 38               corrected            0.001            0.001            0.001
# 39               corrected            0.001            0.001            0.001
# 40               corrected            0.001            0.001            0.001
# 41               corrected            0.001            0.001            0.001
# 42               corrected            0.001            0.001            0.001
# 43               corrected            0.001            0.001            0.001
# 44               corrected            0.001            0.001            0.001
# 45               corrected            0.001            0.001            0.001
# 46               corrected            0.001            0.001            0.001
# 47               corrected            0.001            0.001            0.001
# 48               corrected            0.001            0.001            0.001
# 49               corrected            0.001            0.001            0.001
# 50               corrected            0.001            0.001            0.001
# 51               corrected            0.001            0.001            0.001
# 52               corrected            0.001            0.001            0.001
# 53               corrected            0.001            0.001            0.001
# 54               corrected            0.001            0.001            0.001
# 55               corrected            0.001            0.001            0.001
# 56               corrected            0.001            0.001            0.001
# 57               corrected            0.001            0.001            0.001
# 58               corrected            0.001            0.001            0.001
# 59               corrected            0.001            0.001            0.001
# 60               corrected            0.001            0.001            0.001
# 61               corrected            0.001            0.001            0.001
# 62               corrected            0.001            0.001            0.001
# 63               corrected            0.001            0.001            0.001
# 64               corrected            0.001            0.001            0.001
# 65               corrected            0.001            0.001            0.001
# 66               corrected            0.001            0.001            0.001
# 67               corrected            0.001            0.001            0.001
# 68               corrected            0.001            0.001            0.001
# 69               corrected            0.001            0.001            0.001
# 70               corrected            0.001            0.001            0.001
# 71               corrected            0.001            0.001            0.001
# 72               corrected            0.001            0.001            0.001
# 73               corrected            0.001            0.001            0.001
# 74               corrected            0.001            0.001            0.001
# 75               corrected            0.001            0.001            0.001
# 76               corrected            0.001            0.001            0.001
# 77               corrected            0.001            0.001            0.001
# 78               corrected            0.001            0.001            0.001
# 79               corrected            0.001            0.001            0.001
# 80               corrected            0.001            0.001            0.001
# 81               corrected            0.001            0.001            0.001
# 82               corrected            0.001            0.001            0.001
# 83               corrected            0.001            0.001            0.001
# 84               corrected            0.001            0.001            0.001
# 85               corrected            0.001            0.001            0.001
# 86               corrected            0.001            0.001            0.001
# 87               corrected            0.001            0.001            0.001
# 88               corrected            0.001            0.001            0.001
# 89               corrected            0.001            0.001            0.001
# 90               corrected            0.001            0.001            0.001
# 91               corrected            0.001            0.001            0.001
# 92               corrected            0.001            0.001            0.001
# 93               corrected            0.001            0.001            0.001
# 94               corrected            0.001            0.001            0.001
# 95               corrected            0.001            0.001            0.001
# 96               corrected            0.001            0.001            0.001
# 97               corrected            0.001            0.001            0.001
# 98               corrected            0.001            0.001            0.001
# 99               corrected            0.001            0.001            0.001
# 100              corrected            0.001            0.001            0.001
# 101              corrected            0.001            0.001            0.001
# 102              corrected            0.001            0.001            0.001
# 103              corrected            0.001            0.001            0.001
# 104              corrected            0.001            0.001            0.001
# 105              corrected            0.001            0.001            0.001
# 106              corrected            0.001            0.001            0.001
# 107              corrected            0.001            0.001            0.001
# 108              corrected            0.001            0.001            0.001
# 109              corrected            0.001            0.001            0.001
#
#      tn5_footprint_4  tn5_footprint_5
# 0              0.002            0.001
# 1              0.002            0.001
# 2              0.002            0.001
# 3              0.002            0.001
# 4              0.002            0.001
# 5              0.001            0.001
# 6              0.002            0.001
# 7              0.001            0.001
# 8              0.001            0.001
# 9              0.001            0.001
# 10             0.001            0.001
# 11             0.001            0.001
# 12             0.001            0.001
# 13             0.001            0.001
# 14             0.001            0.001
# 15             0.001            0.001
# 16             0.001            0.001
# 17             0.001            0.001
# 18             0.001            0.001
# 19             0.001            0.001
# 20             0.001            0.001
# 21             0.002            0.001
# 22             0.001            0.001
# 23             0.001            0.001
# 24             0.001            0.001
# 25             0.001            0.001
# 26             0.001            0.001
# 27             0.001            0.001
# 28             0.001            0.001
# 29             0.001            0.001
# 30             0.001            0.001
# 31             0.001            0.001
# 32             0.001            0.001
# 33             0.001            0.001
# 34             0.001            0.001
# 35             0.001            0.001
# 36             0.001            0.001
# 37             0.001            0.001
# 38             0.002            0.001
# 39             0.001            0.001
# 40             0.001            0.001
# 41             0.001            0.001
# 42             0.001            0.001
# 43             0.001            0.001
# 44             0.001            0.001
# 45             0.001            0.001
# 46             0.001            0.001
# 47             0.001            0.001
# 48             0.001            0.001
# 49             0.001            0.001
# 50             0.001            0.001
# 51             0.001            0.001
# 52             0.001            0.001
# 53             0.001            0.001
# 54             0.001            0.001
# 55             0.001            0.001
# 56             0.001            0.001
# 57             0.001            0.001
# 58             0.001            0.001
# 59             0.001            0.001
# 60             0.001            0.001
# 61             0.001            0.001
# 62             0.001            0.001
# 63             0.001            0.001
# 64             0.001            0.001
# 65             0.001            0.001
# 66             0.001            0.001
# 67             0.001            0.001
# 68             0.001            0.001
# 69             0.002            0.001
# 70             0.001            0.001
# 71             0.001            0.001
# 72             0.001            0.001
# 73             0.001            0.001
# 74             0.001            0.001
# 75             0.001            0.001
# 76             0.001            0.001
# 77             0.001            0.001
# 78             0.001            0.001
# 79             0.002            0.001
# 80             0.001            0.001
# 81             0.001            0.001
# 82             0.001            0.001
# 83             0.001            0.001
# 84             0.001            0.001
# 85             0.001            0.001
# 86             0.002            0.001
# 87             0.001            0.001
# 88             0.001            0.001
# 89             0.001            0.001
# 90             0.001            0.001
# 91             0.001            0.001
# 92             0.001            0.001
# 93             0.001            0.001
# 94             0.001            0.001
# 95             0.002            0.002
# 96             0.002            0.001
# 97             0.001            0.001
# 98             0.002            0.001
# 99             0.002            0.002
# 100            0.001            0.001
# 101            0.001            0.001
# 102            0.001            0.001
# 103            0.001            0.001
# 104            0.001            0.001
# 105            0.001            0.001
# 106            0.001            0.001
# 107            0.001            0.001
# 108            0.001            0.001
# 109            0.001            0.001

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['bias_correction_status'] != 'corrected']
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df['tn5_footprint_1'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df['tn5_footprint_2'].max()
# Out:
# 0.002

# %%
cell_type_metrics_df['tn5_footprint_3'].max()
# Out:
# 0.001

# %%
cell_type_metrics_df['tn5_footprint_4'].max()
# Out:
# 0.002

# %%
cell_type_metrics_df['tn5_footprint_5'].max()
# Out:
# 0.002

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_1'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_2'] > 0.001]
# Out:
#   celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 0       c5  fold_0        0.702857          0.67304          0.595972
#
#   bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 0              corrected            0.001            0.002            0.001
#
#    tn5_footprint_4  tn5_footprint_5
# 0            0.002            0.001

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_3'] > 0.001]
# Out:
# Empty DataFrame
# Columns: [celltype, fold, peaks_pearsonr, peaks_spearmanr, peaks_median_jsd, bias_correction_status, tn5_footprint_1, tn5_footprint_2, tn5_footprint_3, tn5_footprint_4, tn5_footprint_5]
# Index: []

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_4'] > 0.001]
# Out:
#    celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 0        c5  fold_0        0.702857         0.673040          0.595972
# 1        c5  fold_1        0.679659         0.637248          0.605662
# 2        c5  fold_2        0.689195         0.655785          0.598982
# 3        c5  fold_3        0.680604         0.641443          0.603978
# 4        c5  fold_4        0.696520         0.674770          0.594759
# 6        c9  fold_1        0.665439         0.640120          0.583305
# 21      c10  fold_1        0.687562         0.670253          0.632722
# 38      c11  fold_3        0.665222         0.635262          0.533395
# 69      c21  fold_4        0.714535         0.713812          0.702006
# 79      c14  fold_4        0.686326         0.671393          0.553336
# 86       c6  fold_1        0.689449         0.651861          0.487854
# 95      c15  fold_0        0.696388         0.694603          0.646583
# 96      c15  fold_1        0.700315         0.694514          0.648157
# 98      c15  fold_3        0.689370         0.687954          0.650106
# 99      c15  fold_4        0.701134         0.700381          0.642462
#
#    bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 0               corrected            0.001            0.002            0.001
# 1               corrected            0.001            0.001            0.001
# 2               corrected            0.001            0.001            0.001
# 3               corrected            0.001            0.001            0.001
# 4               corrected            0.001            0.001            0.001
# 6               corrected            0.001            0.001            0.001
# 21              corrected            0.001            0.001            0.001
# 38              corrected            0.001            0.001            0.001
# 69              corrected            0.001            0.001            0.001
# 79              corrected            0.001            0.001            0.001
# 86              corrected            0.001            0.001            0.001
# 95              corrected            0.001            0.001            0.001
# 96              corrected            0.001            0.001            0.001
# 98              corrected            0.001            0.001            0.001
# 99              corrected            0.001            0.001            0.001
#
#     tn5_footprint_4  tn5_footprint_5
# 0             0.002            0.001
# 1             0.002            0.001
# 2             0.002            0.001
# 3             0.002            0.001
# 4             0.002            0.001
# 6             0.002            0.001
# 21            0.002            0.001
# 38            0.002            0.001
# 69            0.002            0.001
# 79            0.002            0.001
# 86            0.002            0.001
# 95            0.002            0.002
# 96            0.002            0.001
# 98            0.002            0.001
# 99            0.002            0.002

# %%
cell_type_metrics_df.loc[cell_type_metrics_df['tn5_footprint_5'] > 0.001]
# Out:
#    celltype    fold  peaks_pearsonr  peaks_spearmanr  peaks_median_jsd  \
# 95      c15  fold_0        0.696388         0.694603          0.646583
# 99      c15  fold_4        0.701134         0.700381          0.642462
#
#    bias_correction_status  tn5_footprint_1  tn5_footprint_2  tn5_footprint_3  \
# 95              corrected            0.001            0.001            0.001
# 99              corrected            0.001            0.001            0.001
#
#     tn5_footprint_4  tn5_footprint_5
# 95            0.002            0.002
# 99            0.002            0.002

# %%
median_peaks_pearson_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_pearsonr'].median().reset_index()
sorted_peaks_pearson_scores_by_celltype = median_peaks_pearson_scores_by_celltype.sort_values('peaks_pearsonr', ascending=False)['celltype']

median_peaks_spearman_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_spearmanr'].median().reset_index()
sorted_peaks_spearman_scores_by_celltype = median_peaks_spearman_scores_by_celltype.sort_values('peaks_spearmanr', ascending=False)['celltype']

median_peaks_jsd_scores_by_celltype = cell_type_metrics_df.groupby('celltype')['peaks_median_jsd'].median().reset_index()
sorted_peaks_jsd_scores_by_celltype = median_peaks_jsd_scores_by_celltype.sort_values('peaks_median_jsd', ascending=False)['celltype']

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_pearsonr', data=cell_type_metrics_df, order=sorted_peaks_pearson_scores_by_celltype)
plt.title('Distribution of Pearson Correlation Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('Pearson Correlation', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
# plt.ylim(0.60, 0.90)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_spearmanr', data=cell_type_metrics_df, order=sorted_peaks_spearman_scores_by_celltype)
plt.title('Distribution of Spearman Correlation Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('Pearson Correlation', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
# plt.ylim(0.60, 0.90)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(x='celltype', y='peaks_median_jsd', data=cell_type_metrics_df, order=sorted_peaks_jsd_scores_by_celltype)
plt.title('Distribution of JSD Scores in Peaks by Cell Type', fontsize=18, pad=20)
plt.xlabel('Cell Type', fontsize=16, labelpad=20)
plt.ylabel('JSD', fontsize=16, labelpad=20)
plt.xticks(rotation=45, fontsize=14)  # Rotate the cell type labels to make them readable
plt.yticks(fontsize=14)
plt.tight_layout()  # Adjust the layout

plt.show()

# %%
cell_type_metrics_df.to_csv(os.path.join(outs_dir, 'model_performance.tsv'),
                            index=False, sep='\t')
