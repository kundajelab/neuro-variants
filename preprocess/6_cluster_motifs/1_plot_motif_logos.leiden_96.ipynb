# %%
import MotifCompendium
import MotifCompendium.utils.analysis as utils_analysis
import MotifCompendium.utils.motif as utils_motif
from MotifCompendium.utils.similarity import set_default_options
from IPython.display import display, HTML, Image
from typing import List, Union
import pandas as pd
import numpy as np
import os
import h5py

import matplotlib
matplotlib.use('pdf')
from matplotlib import pyplot as plt
import logomaker

# %%
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = "2"
set_default_options(max_chunk=1000, max_cpus=32, use_gpu=True)

# %%
mc_h5_file = '/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/leiden_96/neuro-variants.all_data.motif_compendium.avg.leiden_96.h5'
selin_h5_file = '/oak/stanford/groups/akundaje/soumyak/motifs/latest/selin/selin.motif_compendium.avg.h5'
hocomoco_meme_file = '/oak/stanford/groups/akundaje/soumyak/motifs/latest/hocomoco_v12/H12CORE_meme_format.meme'
vierstra_meme_file = '/oak/stanford/groups/akundaje/soumyak/motifs/latest/vierstra/all.dbs.meme'
metadata_file = '/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/leiden_96/neuro-variants.all_data.motif_compendium.avg.metadata.leiden_96.tsv'

logo_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/logos'

# %%
def _plot_weights(array, path, figsize=(10,3)):
	"""Plot weights as a sequence logo and save to file."""

	if not os.path.isfile(path):
		fig = plt.figure(figsize=figsize)
		ax = fig.add_subplot(111) 

		df = pd.DataFrame(array, columns=['A', 'C', 'G', 'T'])
		df.index.name = 'pos'

		crp_logo = logomaker.Logo(df, ax=ax)
		crp_logo.style_spines(visible=False)
		plt.ylim(min(df.sum(axis=1).min(), 0), df.sum(axis=1).max())

		plt.savefig(path)
		plt.close()

	else:
		pass

# %%
def create_modisco_logos(modisco_h5py: os.PathLike, modisco_logo_dir, trim_threshold, pattern_groups: List[str]):
	"""Open a modisco results file and create and write logos to file for each pattern."""
	modisco_results = h5py.File(modisco_h5py, 'r')

	tags = []

	for name in pattern_groups:
		if name not in modisco_results.keys():
			continue

		metacluster = modisco_results[name]
		key = lambda x: int(x[0].split("_")[-1])
		for pattern_name, pattern in sorted(metacluster.items(), key=key):
			tag = pattern_name
			tags.append(tag)

			cwm_fwd = np.array(pattern['contrib_scores'][:])
			cwm_rev = cwm_fwd[::-1, ::-1]

			score_fwd = np.sum(np.abs(cwm_fwd), axis=1)
			score_rev = np.sum(np.abs(cwm_rev), axis=1)

			trim_thresh_fwd = np.max(score_fwd) * trim_threshold
			trim_thresh_rev = np.max(score_rev) * trim_threshold

			pass_inds_fwd = np.where(score_fwd >= trim_thresh_fwd)[0]
			pass_inds_rev = np.where(score_rev >= trim_thresh_rev)[0]

			start_fwd, end_fwd = max(np.min(pass_inds_fwd) - 4, 0), min(np.max(pass_inds_fwd) + 4 + 1, len(score_fwd) + 1)
			start_rev, end_rev = max(np.min(pass_inds_rev) - 4, 0), min(np.max(pass_inds_rev) + 4 + 1, len(score_rev) + 1)

			trimmed_cwm_fwd = cwm_fwd[start_fwd:end_fwd]
			trimmed_cwm_rev = cwm_rev[start_rev:end_rev]

			_plot_weights(trimmed_cwm_fwd, path='{}/{}.cwm.fwd.png'.format(modisco_logo_dir, tag))
			_plot_weights(trimmed_cwm_rev, path='{}/{}.cwm.rev.png'.format(modisco_logo_dir, tag))

	modisco_results.close()
	return tags

# %%
def create_selin_logos(modisco_h5py: os.PathLike, modisco_logo_dir, trim_threshold, pattern_groups: List[str]):
	"""Open a modisco results file and create and write logos to file for each pattern."""
	modisco_results = h5py.File(modisco_h5py, 'r')

	tags = []

	for name in pattern_groups:
		if name not in modisco_results.keys():
			continue

		metacluster = modisco_results[name]
		for pattern_name, pattern in metacluster.items():
			tag = pattern_name.replace('/', '-').replace("#", "-")
			tags.append(tag)

			cwm_fwd = np.array(pattern['contrib_scores'][:])
			cwm_rev = cwm_fwd[::-1, ::-1]

			score_fwd = np.sum(np.abs(cwm_fwd), axis=1)
			score_rev = np.sum(np.abs(cwm_rev), axis=1)

			trim_thresh_fwd = np.max(score_fwd) * trim_threshold
			trim_thresh_rev = np.max(score_rev) * trim_threshold

			pass_inds_fwd = np.where(score_fwd >= trim_thresh_fwd)[0]
			pass_inds_rev = np.where(score_rev >= trim_thresh_rev)[0]

			start_fwd, end_fwd = max(np.min(pass_inds_fwd) - 4, 0), min(np.max(pass_inds_fwd) + 4 + 1, len(score_fwd) + 1)
			start_rev, end_rev = max(np.min(pass_inds_rev) - 4, 0), min(np.max(pass_inds_rev) + 4 + 1, len(score_rev) + 1)

			trimmed_cwm_fwd = cwm_fwd[start_fwd:end_fwd]
			trimmed_cwm_rev = cwm_rev[start_rev:end_rev]

			_plot_weights(trimmed_cwm_fwd, path='{}/{}.cwm.fwd.png'.format(modisco_logo_dir, tag))
			_plot_weights(trimmed_cwm_rev, path='{}/{}.cwm.rev.png'.format(modisco_logo_dir, tag))

	modisco_results.close()
	return tags

# %%
def read_meme(filename):
	motifs = {}

	with open(filename, "r") as infile:
		motif, width, i = None, None, 0

		for line in infile:
			if motif is None:
				if line[:5] == 'MOTIF':
					motif = line.split()[1]
				else:
					continue

			elif width is None:
				if line[:6] == 'letter':
					width = int(line.split()[5])
					pwm = np.zeros((width, 4))

			elif i < width:
				pwm[i] = list(map(float, line.split()))
				i += 1

			else:
				motifs[motif] = pwm
				motif, width, i = None, None, 0

	return motifs

# %%
def compute_per_position_ic(ppm, background, pseudocount):
    alphabet_len = len(background)
    ic = ((np.log((ppm+pseudocount)/(1 + pseudocount*alphabet_len))/np.log(2))
          *ppm - (np.log(background)*background/np.log(2))[None,:])
    return np.sum(ic,axis=1)

# %%
def make_logo(match, logo_dir, motifs):
	if match == 'NA':
		return

	background = np.array([0.25, 0.25, 0.25, 0.25])
	ppm = motifs[match]
	ic = compute_per_position_ic(ppm, background, 0.001)

	_plot_weights(ppm*ic[:, None], path='{}/{}.png'.format(logo_dir, match))

# %%
def path_to_image_link(path):
    return '=IMAGE("' + path + '#"&RANDBETWEEN(1111111,9999999), 4, 80, 240)'

# %%
mc_h5 = h5py.File(mc_h5_file, 'r')

mc_h5.keys()
# Out:
# <KeysViewHDF5 ['neg_patterns', 'pos_patterns']>

# %%
selin_h5 = h5py.File(selin_h5_file, 'r')

selin_h5.keys()
# Out:
# <KeysViewHDF5 ['neg_patterns', 'pos_patterns']>

# %%
modisco_logo_dir = os.path.join(logo_dir, 'modisco/all_data/leiden_96')
if not os.path.isdir(modisco_logo_dir):
    os.mkdir(modisco_logo_dir)

pattern_groups = [group for group in mc_h5.keys()]
print(pattern_groups)

trim_threshold = 0.1

create_modisco_logos(mc_h5_file, modisco_logo_dir, trim_threshold, ['pos_patterns'])
create_modisco_logos(mc_h5_file, modisco_logo_dir, trim_threshold, ['neg_patterns'])
# Out:
# ['neg_patterns', 'pos_patterns']
# ['neg_patterns.pattern_0',
#  'neg_patterns.pattern_1',
#  'neg_patterns.pattern_2',
#  'neg_patterns.pattern_3',
#  'neg_patterns.pattern_4',
#  'neg_patterns.pattern_5',
#  'neg_patterns.pattern_6',
#  'neg_patterns.pattern_7',
#  'neg_patterns.pattern_8',
#  'neg_patterns.pattern_9',
#  'neg_patterns.pattern_10',
#  'neg_patterns.pattern_11',
#  'neg_patterns.pattern_12',
#  'neg_patterns.pattern_13',
#  'neg_patterns.pattern_14',
#  'neg_patterns.pattern_15',
#  'neg_patterns.pattern_16',
#  'neg_patterns.pattern_17',
#  'neg_patterns.pattern_18',
#  'neg_patterns.pattern_19',
#  'neg_patterns.pattern_20',
#  'neg_patterns.pattern_21',
#  'neg_patterns.pattern_22',
#  'neg_patterns.pattern_23',
#  'neg_patterns.pattern_24',
#  'neg_patterns.pattern_25',
#  'neg_patterns.pattern_26',
#  'neg_patterns.pattern_27',
#  'neg_patterns.pattern_28',
#  'neg_patterns.pattern_29',
#  'neg_patterns.pattern_30',
#  'neg_patterns.pattern_31',
#  'neg_patterns.pattern_32',
#  'neg_patterns.pattern_33',
#  'neg_patterns.pattern_34',
#  'neg_patterns.pattern_35',
#  'neg_patterns.pattern_36',
#  'neg_patterns.pattern_37',
#  'neg_patterns.pattern_38',
#  'neg_patterns.pattern_39',
#  'neg_patterns.pattern_40',
#  'neg_patterns.pattern_41',
#  'neg_patterns.pattern_42',
#  'neg_patterns.pattern_43',
#  'neg_patterns.pattern_44',
#  'neg_patterns.pattern_45',
#  'neg_patterns.pattern_46',
#  'neg_patterns.pattern_47',
#  'neg_patterns.pattern_48',
#  'neg_patterns.pattern_49',
#  'neg_patterns.pattern_50',
#  'neg_patterns.pattern_51',
#  'neg_patterns.pattern_52',
#  'neg_patterns.pattern_53',
#  'neg_patterns.pattern_54',
#  'neg_patterns.pattern_55',
#  'neg_patterns.pattern_56',
#  'neg_patterns.pattern_57',
#  'neg_patterns.pattern_58',
#  'neg_patterns.pattern_59',
#  'neg_patterns.pattern_60',
#  'neg_patterns.pattern_61',
#  'neg_patterns.pattern_62',
#  'neg_patterns.pattern_63',
#  'neg_patterns.pattern_64',
#  'neg_patterns.pattern_65',
#  'neg_patterns.pattern_66',
#  'neg_patterns.pattern_67',
#  'neg_patterns.pattern_68',
#  'neg_patterns.pattern_69',
#  'neg_patterns.pattern_70',
#  'neg_patterns.pattern_71',
#  'neg_patterns.pattern_72',
#  'neg_patterns.pattern_73',
#  'neg_patterns.pattern_74',
#  'neg_patterns.pattern_75',
#  'neg_patterns.pattern_76',
#  'neg_patterns.pattern_77',
#  'neg_patterns.pattern_78',
#  'neg_patterns.pattern_79',
#  'neg_patterns.pattern_80',
#  'neg_patterns.pattern_81',
#  'neg_patterns.pattern_82',
#  'neg_patterns.pattern_83',
#  'neg_patterns.pattern_84',
#  'neg_patterns.pattern_85',
#  'neg_patterns.pattern_86',
#  'neg_patterns.pattern_87',
#  'neg_patterns.pattern_88',
#  'neg_patterns.pattern_89',
#  'neg_patterns.pattern_90',
#  'neg_patterns.pattern_91',
#  'neg_patterns.pattern_92',
#  'neg_patterns.pattern_93',
#  'neg_patterns.pattern_94',
#  'neg_patterns.pattern_95',
#  'neg_patterns.pattern_96',
#  'neg_patterns.pattern_97',
#  'neg_patterns.pattern_98',
#  'neg_patterns.pattern_99',
#  'neg_patterns.pattern_100',
#  'neg_patterns.pattern_101',
#  'neg_patterns.pattern_102',
#  'neg_patterns.pattern_103',
#  'neg_patterns.pattern_104',
#  'neg_patterns.pattern_105',
#  'neg_patterns.pattern_106',
#  'neg_patterns.pattern_107',
#  'neg_patterns.pattern_108',
#  'neg_patterns.pattern_109',
#  'neg_patterns.pattern_110',
#  'neg_patterns.pattern_111',
#  'neg_patterns.pattern_112',
#  'neg_patterns.pattern_113',
#  'neg_patterns.pattern_114',
#  'neg_patterns.pattern_115',
#  'neg_patterns.pattern_116',
#  'neg_patterns.pattern_117',
#  'neg_patterns.pattern_118',
#  'neg_patterns.pattern_119',
#  'neg_patterns.pattern_120',
#  'neg_patterns.pattern_121',
#  'neg_patterns.pattern_122',
#  'neg_patterns.pattern_123',
#  'neg_patterns.pattern_124',
#  'neg_patterns.pattern_125',
#  'neg_patterns.pattern_126',
#  'neg_patterns.pattern_127',
#  'neg_patterns.pattern_128',
#  'neg_patterns.pattern_129',
#  'neg_patterns.pattern_130',
#  'neg_patterns.pattern_131',
#  'neg_patterns.pattern_132',
#  'neg_patterns.pattern_133',
#  'neg_patterns.pattern_134',
#  'neg_patterns.pattern_135',
#  'neg_patterns.pattern_136',
#  'neg_patterns.pattern_137',
#  'neg_patterns.pattern_138',
#  'neg_patterns.pattern_139',
#  'neg_patterns.pattern_140',
#  'neg_patterns.pattern_141',
#  'neg_patterns.pattern_142',
#  'neg_patterns.pattern_143',
#  'neg_patterns.pattern_144',
#  'neg_patterns.pattern_145',
#  'neg_patterns.pattern_146',
#  'neg_patterns.pattern_147',
#  'neg_patterns.pattern_148',
#  'neg_patterns.pattern_149',
#  'neg_patterns.pattern_150',
#  'neg_patterns.pattern_151',
#  'neg_patterns.pattern_152',
#  'neg_patterns.pattern_153',
#  'neg_patterns.pattern_154',
#  'neg_patterns.pattern_155',
#  'neg_patterns.pattern_156',
#  'neg_patterns.pattern_157',
#  'neg_patterns.pattern_158',
#  'neg_patterns.pattern_159',
#  'neg_patterns.pattern_160',
#  'neg_patterns.pattern_161',
#  'neg_patterns.pattern_162',
#  'neg_patterns.pattern_163',
#  'neg_patterns.pattern_164',
#  'neg_patterns.pattern_165',
#  'neg_patterns.pattern_166',
#  'neg_patterns.pattern_167',
#  'neg_patterns.pattern_168',
#  'neg_patterns.pattern_169',
#  'neg_patterns.pattern_170',
#  'neg_patterns.pattern_171',
#  'neg_patterns.pattern_172',
#  'neg_patterns.pattern_173',
#  'neg_patterns.pattern_174',
#  'neg_patterns.pattern_175',
#  'neg_patterns.pattern_176',
#  'neg_patterns.pattern_177',
#  'neg_patterns.pattern_178',
#  'neg_patterns.pattern_179',
#  'neg_patterns.pattern_180',
#  'neg_patterns.pattern_181',
#  'neg_patterns.pattern_182',
#  'neg_patterns.pattern_183',
#  'neg_patterns.pattern_184',
#  'neg_patterns.pattern_185',
#  'neg_patterns.pattern_186',
#  'neg_patterns.pattern_187',
#  'neg_patterns.pattern_188',
#  'neg_patterns.pattern_189',
#  'neg_patterns.pattern_190',
#  'neg_patterns.pattern_191',
#  'neg_patterns.pattern_192',
#  'neg_patterns.pattern_193',
#  'neg_patterns.pattern_194',
#  'neg_patterns.pattern_195',
#  'neg_patterns.pattern_196',
#  'neg_patterns.pattern_197',
#  'neg_patterns.pattern_198',
#  'neg_patterns.pattern_199',
#  'neg_patterns.pattern_200',
#  'neg_patterns.pattern_201',
#  'neg_patterns.pattern_202',
#  'neg_patterns.pattern_203',
#  'neg_patterns.pattern_204',
#  'neg_patterns.pattern_205',
#  'neg_patterns.pattern_206',
#  'neg_patterns.pattern_207',
#  'neg_patterns.pattern_208',
#  'neg_patterns.pattern_209',
#  'neg_patterns.pattern_210',
#  'neg_patterns.pattern_211',
#  'neg_patterns.pattern_212',
#  'neg_patterns.pattern_213',
#  'neg_patterns.pattern_214',
#  'neg_patterns.pattern_215',
#  'neg_patterns.pattern_216',
#  'neg_patterns.pattern_217',
#  'neg_patterns.pattern_218',
#  'neg_patterns.pattern_219',
#  'neg_patterns.pattern_220',
#  'neg_patterns.pattern_221',
#  'neg_patterns.pattern_222',
#  'neg_patterns.pattern_223',
#  'neg_patterns.pattern_224',
#  'neg_patterns.pattern_225',
#  'neg_patterns.pattern_226',
#  'neg_patterns.pattern_227',
#  'neg_patterns.pattern_228',
#  'neg_patterns.pattern_229',
#  'neg_patterns.pattern_230',
#  'neg_patterns.pattern_231',
#  'neg_patterns.pattern_232',
#  'neg_patterns.pattern_233',
#  'neg_patterns.pattern_234',
#  'neg_patterns.pattern_235',
#  'neg_patterns.pattern_236',
#  'neg_patterns.pattern_237',
#  'neg_patterns.pattern_238',
#  'neg_patterns.pattern_239',
#  'neg_patterns.pattern_240',
#  'neg_patterns.pattern_241',
#  'neg_patterns.pattern_242',
#  'neg_patterns.pattern_243',
#  'neg_patterns.pattern_244',
#  'neg_patterns.pattern_245',
#  'neg_patterns.pattern_246',
#  'neg_patterns.pattern_247',
#  'neg_patterns.pattern_248',
#  'neg_patterns.pattern_249',
#  'neg_patterns.pattern_250',
#  'neg_patterns.pattern_251',
#  'neg_patterns.pattern_252',
#  'neg_patterns.pattern_253',
#  'neg_patterns.pattern_254',
#  'neg_patterns.pattern_255',
#  'neg_patterns.pattern_256',
#  'neg_patterns.pattern_257',
#  'neg_patterns.pattern_258',
#  'neg_patterns.pattern_259',
#  'neg_patterns.pattern_260',
#  'neg_patterns.pattern_261',
#  'neg_patterns.pattern_262',
#  'neg_patterns.pattern_263',
#  'neg_patterns.pattern_264',
#  'neg_patterns.pattern_265',
#  'neg_patterns.pattern_266',
#  'neg_patterns.pattern_267',
#  'neg_patterns.pattern_268',
#  'neg_patterns.pattern_269',
#  'neg_patterns.pattern_270',
#  'neg_patterns.pattern_271',
#  'neg_patterns.pattern_272',
#  'neg_patterns.pattern_273']

# %%
selin_logo_dir = os.path.join(logo_dir, 'selin')
if not os.path.isdir(selin_logo_dir):
    os.mkdir(selin_logo_dir)

pattern_groups = [group for group in selin_h5.keys()]
print(pattern_groups)

trim_threshold = 0.1

create_selin_logos(selin_h5_file, selin_logo_dir, trim_threshold, ['pos_patterns'])
create_selin_logos(selin_h5_file, selin_logo_dir, trim_threshold, ['neg_patterns'])
# Out:
# ['neg_patterns', 'pos_patterns']
# ['BCL11A-Brepressive',
#  'HIC',
#  'NFYrepressive',
#  'YY1-2repressive',
#  'ZEB-SNAI',
#  'ZEB-SNAI_ZEB-SNAI-1',
#  'ZEB-SNAI_ZEB-SNAI-2',
#  'ZEB-SNAI_ZEB-SNAI-3',
#  'ZEB-SNAI_ZEB-SNAI-4',
#  'ZEB-SNAI_ZEB-SNAI-5',
#  'unresolved,repressive-1',
#  'unresolved,repressive-2',
#  'unresolved,repressive,YY1-2-like',
#  'unresolved,repressive,ZEB-SNAI-like']

# %%
metadata = pd.read_table(metadata_file)
metadata['selin_match'] = metadata['selin_match'].str.replace('/', '-')
metadata['selin_match'] = metadata['selin_match'].str.replace("#", "-")

metadata
# Out:
#      index                      name  num_patterns  num_seqlets  num_samples  \
# 0        0    pos_patterns.pattern_0            74       194827           53
# 1        1    pos_patterns.pattern_1            58       372948           54
# 2        2    pos_patterns.pattern_2            55       137965           53
# 3        3    pos_patterns.pattern_3            54        92698           54
# 4        4    pos_patterns.pattern_4            54       317250           54
# ..     ...                       ...           ...          ...          ...
# 994    994  pos_patterns.pattern_720             1           28            1
# 995    995  pos_patterns.pattern_721             1           27            1
# 996    996  pos_patterns.pattern_722             1           26            1
# 997    997  pos_patterns.pattern_723             1           24            1
# 998    998  pos_patterns.pattern_724             1           22            1
#
#      num_datasets                              datasets posneg  \
# 0               3  corces_2020,domcke_2020,trevino_2021    pos
# 1               3  corces_2020,domcke_2020,trevino_2021    pos
# 2               3  corces_2020,domcke_2020,trevino_2021    pos
# 3               3  corces_2020,domcke_2020,trevino_2021    pos
# 4               3  corces_2020,domcke_2020,trevino_2021    pos
# ..            ...                                   ...    ...
# 994             1                           corces_2020    pos
# 995             1                           corces_2020    pos
# 996             1                           corces_2020    pos
# 997             1                           corces_2020    pos
# 998             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 994             0.912841  RFX1.H12CORE.1.PSM.A             0.922637
# 995             0.908444   CEBPD.H12CORE.0.P.B             0.907553
# 996             0.898491    MITF.H12CORE.0.P.B             0.854161
# 997             0.901590   RUNX2.H12CORE.0.P.B             0.919790
# 998             0.825721   FOSL1.H12CORE.0.P.B             0.839746
#
#          vierstra_match  selin_similarity                     selin_match  \
# 0      NRF1_M09443_2.00          0.998523                            NRF1
# 1       SP4_M08296_2.00          0.998351                          SP-KLF
# 2     CREB1_M04258_2.00          0.998884                 BZIP:ATF-CREB-1
# 3      ETS1_M07950_2.00          0.999409                        ZNF143-1
# 4         NFYA_MA0060.1          0.999510                             NFY
# ..                  ...               ...                             ...
# 994    RFX2_M09362_2.00          0.962012                           RFX-1
# 995   CEBPA_M08813_2.00          0.930452                     BZIP:CEBP-1
# 996  ZNF317_M08308_2.00          0.888819                   BHLH:USF1-2-1
# 997   RUNX3_M02751_2.00          0.937730                          RUNX-1
# 998     JUN_M07837_2.00          0.875790  BZIP:FOSL-JUND_NR:ESRRA-NR5A-1
#
#             annotation
# 0               NRF1_0
# 1             SP-KLF_1
# 2    BZIP:ATF-CREB-1_2
# 3           ZNF143-1_3
# 4                NFY_4
# ..                 ...
# 994          RFX-1_994
# 995        Unknown_995
# 996        Unknown_996
# 997        Unknown_997
# 998        Unknown_998
#
# [999 rows x 15 columns]

# %%
hocomoco_meme = read_meme(hocomoco_meme_file)
vierstra_meme = read_meme(vierstra_meme_file)

# %%
hocomoco_meme.keys()
# Out:
# dict_keys(['AHR.H12CORE.0.P.B', 'AHRR.H12CORE.0.P.C', 'ALX1.H12CORE.0.SM.B', 'ALX3.H12CORE.0.SM.B', 'ALX3.H12CORE.1.S.B', 'ALX4.H12CORE.0.S.B', 'ALX4.H12CORE.1.SM.B', 'ANDR.H12CORE.0.P.B', 'ANDR.H12CORE.1.S.C', 'ANDR.H12CORE.2.P.B', 'AP2A.H12CORE.0.PSM.A', 'AP2B.H12CORE.0.SM.B', 'AP2C.H12CORE.0.PSM.A', 'AP2E.H12CORE.0.SM.B', 'ARGFX.H12CORE.0.SM.B', 'ARI1A.H12CORE.0.P.C', 'ARNT.H12CORE.0.P.B', 'ARNT.H12CORE.1.P.B', 'ARNT2.H12CORE.0.P.B', 'ARNT2.H12CORE.1.P.B', 'ARNT2.H12CORE.2.S.C', 'ARX.H12CORE.0.S.B', 'ARX.H12CORE.1.SM.B', 'ASCL1.H12CORE.0.PSM.A', 'ASCL2.H12CORE.0.PSM.A', 'ATF1.H12CORE.0.P.B', 'ATF1.H12CORE.1.P.B', 'ATF2.H12CORE.0.PSM.A', 'ATF2.H12CORE.1.P.B', 'ATF3.H12CORE.0.P.B', 'ATF3.H
# 5191  ['C2H2 zinc finger factors']    Unknown  22955616
# 5192      ['Homeo domain factors']    Unknown  18585359
#
# [5193 rows x 7 columns]

# %%
vierstra_subset = vierstra_metadata.loc[vierstra_metadata.apply(lambda x: x['tf_name'] + '_' + x['motif_id'] in metadata['vierstra_match'].values,
                                                                axis=1)]

vierstra_subset
# Out:
#             motif_id cluster    source_id       tf_name  \
# 0     BANP_Grand2021  AC0375         BANP          BANP
# 4        M00220_2.00  AC0606  SNAI2_D119E         SNAI2
# 5        M00221_2.00  AC0606    SNAI2_REF         SNAI2
# 6        M00222_2.00  AC0606  SNAI2_T234I         SNAI2
# 7        M00223_2.00  AC0111   KLF1_E325K          KLF1
# ...              ...     ...          ...           ...
# 5122        MA1721.1  AC0460     MA1721.1         ZNF93
# 5132        MA1928.1  AC0242     MA1928.1          BNC2
# 5137        MA1933.1  AC0626     MA1933.1  ELK1::SREBF2
# 5139        MA1935.1  AC0626     MA1935.1    ERF::FOXI1
# 5188        MA1984.1  AC0490     MA1984.1        ZNF667
#
#                                             family_name motif_type      PMID
# 0                                               Unknown   ChIP-seq  34234345
# 4                                               C2H2 ZF        PBM  27013732
# 5                                               C2H2 ZF        PBM  27013732
# 6                                               C2H2 ZF        PBM  27013732
# 7                                               C2H2 ZF        PBM  27013732
# ...                                                 ...        ...       ...
# 5122                       ['C2H2 zinc finger factors']    Unknown  25274305
# 5132                       ['C2H2 zinc finger factors']    Unknown  30487138
# 5137  ['Tryptophan cluster factors', 'Basic helix-lo...    Unknown  23050235
# 5139  ['Tryptophan cluster factors', 'Fork head/wing...    Unknown  31913281
# 5188                       ['C2H2 zinc finger factors']    Unknown  27852650
#
# [471 rows x 7 columns]

# %%
vierstra_meme_subset = {}

for index,row in vierstra_subset.iterrows():
    vierstra_meme_subset[row['tf_name'] + '_' + row['motif_id']] = vierstra_meme[row['motif_id']]

# %%
hocomoco_meme_subset = {key: hocomoco_meme[key] for key in hocomoco_meme.keys() if key in metadata['hocomoco_match'].values}

# %%
vierstra_meme_subset.keys()
# Out:
# dict_keys(['BANP_BANP_Grand2021', 'SNAI2_M00220_2.00', 'SNAI2_M00221_2.00', 'SNAI2_M00222_2.00', 'KLF1_M00223_2.00', 'KLF1_M00224_2.00', 'EGR2_M00233_2.00', 'GFI1_M00237_2.00', 'ZNF655_M00250_2.00', 'ZNF655_M00251_2.00', 'FOXC1_M00255_2.00', 'VSX2_M00285_2.00', 'VENTX_M00304_2.00', 'VENTX_M00305_2.00', 'PITX2_M00312_2.00', 'HOXB7_M00332_2.00', 'NR1H4_M00367_2.00', 'PHF1_M00967_2.00', 'BCL11A_M00983_2.00', 'BCL11A_M00984_2.00', 'BCL11A_M00985_2.00', 'BCL11B_M00987_2.00', 'BCL11B_M00988_2.00', 'SOX4_M01026_2.00', 'ZSCAN29_M01165_2.00', 'PLAGL2_M01171_2.00', 'VEZF1_M01172_2.00', 'TIGD1_M01204_2.00', 'LCORL_M01304_2.00', 'MAX_M01497_2.00', 'CUX2_M01499_2.00', 'CUX1_M01
.1.PSM.A', 'MAX.H12CORE.1.M.C', 'MBNL2.H12CORE.0.S.C', 'MEF2A.H12CORE.0.P.B', 'MEF2C.H12CORE.0.P.B', 'MEF2C.H12CORE.1.SM.B', 'MEF2D.H12CORE.0.PS.A', 'MEIS1.H12CORE.0.P.B', 'MEIS1.H12CORE.1.PS.A', 'MEIS2.H12CORE.2.SM.B', 'MEOX2.H12CORE.0.SM.B', 'MESP1.H12CORE.0.S.C', 'MITF.H12CORE.0.P.B', 'MLX.H12CORE.0.PM.A', 'MSGN1.H12CORE.0.PSM.A', 'MSX2.H12CORE.1.SM.B', 'MUSC.H12CORE.0.SM.B', 'MYC.H12CORE.0.P.B', 'MYCN.H12CORE.1.M.C', 'MYF5.H12CORE.0.P.B', 'MYT1L.H12CORE.0.P.C', 'NANOG.H12CORE.1.P.B', 'NDF1.H12CORE.1.S.C', 'NDF2.H12CORE.0.P.B', 'NFAT5.H12CORE.0.SM.B', 'NFE2.H12CORE.1.SM.B', 'NFIA.H12CORE.0.P.B', 'NFIB.H12CORE.0.PSM.A', 'NFIB.H12CORE.1.PS.A', 'NFIC.H12CORE.1.PSM.A', 'NFIX.H12CORE.0.SM.B', 'NFIX.H12CORE.1.S.B', 'NFYA.H12CORE.0.P.B', 'NFYB.H12CORE.0.P.B', 'NFYC.H12CORE.0.P.B', 'NGN1.H12CORE.0.SM.B', 'NGN2.H12CORE.0.P.B', 'NGN2.H12CORE.1.SM.B', 'NKX61.H12CORE.0.PS.A', 'NOTO.H12CORE.0.SM.B', 'NR1D1.H12CORE.1.SM.B', 'NR1H2.H12CORE.0.P.C', 'NR1H3.H12CORE.1.P.B', 'NR1H4.H12CORE.0.P.B', 'NR1H4.H12CORE.1.P.B', 'NR2C1.H12CORE.1.PM.A', 'NR2F6.H12CORE.1.PSM.A', 'NRF1.H12CORE.0.PS.A', 'ONEC2.H12CORE.3.P.B', 'P53.H12CORE.0.P.B', 'P53.H12CORE.1.S.C', 'P5F1B.H12CORE.0.S.B', 'P63.H12CORE.1.PS.A', 'P73.H12CORE.1.P.B', 'PAX4.H12CORE.0.SM.B', 'PAX6.H12CORE.0.PSM.A', 'PBX1.H12CORE.1.P.B', 'PBX1.H12CORE.2.P.B', 'PDX1.H12CORE.0.P.B', 'PHX2A.H12CORE.0.PS.A', 'PIT1.H12CORE.0.SM.B', 'PIT1.H12CORE.1.S.B', 'PO2F2.H12CORE.2.S.B', 'PO2F3.H12CORE.0.PS.A', 'PO3F1.H12CORE.0.P.B', 'PO3F1.H12CORE.3.M.C', 'PO3F2.H12CORE.0.P.B', 'PO3F2.H ...

# %%
vierstra_logo_dir = os.path.join(logo_dir, 'vierstra')
if not os.path.isdir(vierstra_logo_dir):
    os.mkdir(vierstra_logo_dir)

for motif in vierstra_meme_subset.keys():
    make_logo(motif, vierstra_logo_dir, vierstra_meme_subset)

# %%
hocomoco_logo_dir = os.path.join(logo_dir, 'hocomoco')
if not os.path.isdir(hocomoco_logo_dir):
    os.mkdir(hocomoco_logo_dir)

for motif in hocomoco_meme_subset.keys():
    make_logo(motif, hocomoco_logo_dir, hocomoco_meme_subset)

# %%
metadata.columns.tolist()
# Out:
# ['index',
#  'name',
#  'num_patterns',
#  'num_seqlets',
#  'num_samples',
#  'num_datasets',
#  'datasets',
#  'posneg',
#  'hocomoco_similarity',
#  'hocomoco_match',
#  'vierstra_similarity',
#  'vierstra_match',
#  'selin_similarity',
#  'selin_match',
#  'annotation']

# %%
logo_link_base = 'https://mitra.stanford.edu/kundaje/oak/projects/neuro-variants/motif_compendium/logos'

metadata['modisco_fwd'] = path_to_image_link(logo_link_base + '/modisco/all_data/leiden_96/' + metadata['name'] + '.cwm.fwd.png')
metadata['modisco_rev'] = path_to_image_link(logo_link_base + '/modisco/all_data/leiden_96/' + metadata['name'] + '.cwm.rev.png')
metadata['selin_fwd'] = path_to_image_link(logo_link_base + '/selin/' + metadata['selin_match'] + '.cwm.fwd.png')
metadata['selin_rev'] = path_to_image_link(logo_link_base + '/selin/' + metadata['selin_match'] + '.cwm.rev.png')
metadata['vierstra_logo'] = path_to_image_link(logo_link_base + '/vierstra/' + metadata['vierstra_match'] + '.png')
metadata['hocomoco_logo'] = path_to_image_link(logo_link_base + '/hocomoco/' + metadata['hocomoco_match'] + '.png')
metadata.rename(columns={'name': 'modisco_pattern',
                         'annotation': 'auto_annotation'},
                         inplace=True)
metadata['manual_annotation'] = ''

metadata = metadata[['modisco_pattern', 'modisco_fwd', 'modisco_rev', 'manual_annotation', 'auto_annotation',
                     'selin_similarity', 'selin_match', 'selin_fwd', 'selin_rev',
                     'vierstra_similarity', 'vierstra_match', 'vierstra_logo',
                     'hocomoco_similarity', 'hocomoco_match', 'hocomoco_logo',
                     'num_patterns', 'num_seqlets', 'num_samples', 'num_datasets',
                     'datasets', 'posneg', 'index']]

metadata
# Out:
#               modisco_pattern  \
# 0      pos_patterns.pattern_0
# 1      pos_patterns.pattern_1
# 2      pos_patterns.pattern_2
# 3      pos_patterns.pattern_3
# 4      pos_patterns.pattern_4
# ..                        ...
# 994  pos_patterns.pattern_720
# 995  pos_patterns.pattern_721
# 996  pos_patterns.pattern_722
# 997  pos_patterns.pattern_723
# 998  pos_patterns.pattern_724
#
#                                            modisco_fwd  \
# 0    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 1    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 2    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 3    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 4    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# ..                                                 ...
# 994  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 995  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 996  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 997  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 998  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
#
#                                            modisco_rev manual_annotation  \
# 0    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 1    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 2    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 3    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 4    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# ..                                                 ...               ...
# 994  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 995  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 996  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 997  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 998  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
#
#        auto_annotation  selin_similarity                     selin_match  \
# 0               NRF1_0          0.998523                            NRF1
# 1             SP-KLF_1          0.998351                          SP-KLF
# 2    BZIP:ATF-CREB-1_2          0.998884                 BZIP:ATF-CREB-1
# 3           ZNF143-1_3          0.999409                        ZNF143-1
# 4                NFY_4          0.999510                             NFY
# ..                 ...               ...                             ...
# 994          RFX-1_994          0.962012                           RFX-1
# 995        Unknown_995          0.930452                     BZIP:CEBP-1
# 996        Unknown_996          0.888819                   BHLH:USF1-2-1
# 997        Unknown_997          0.937730                          RUNX-1
# 998        Unknown_998          0.875790  BZIP:FOSL-JUND_NR:ESRRA-NR5A-1
#
#                                              selin_fwd  \
# 0    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 1    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 2    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 3    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 4    =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# ..                                                 ...
# 994  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 995  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 996  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 997  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
# 998  =IMAGE("https://mitra.stanford.edu/kundaje/oak...
#
#                                              selin_rev  vierstra_similarity  \
# 0    =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.951238
# 1    =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.944662
# 2    =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.973756
# 3    =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.971501
# 4    =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.984840
# ..                                                 ...                  ...
# 994  =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.922637
# 995  =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.907553
# 996  =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.854161
# 997  =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.919790
# 998  =IMAGE("https://mitra.stanford.edu/kundaje/oak...             0.839746
#
#      ... hocomoco_similarity        hocomoco_match  \
# 0    ...            0.914414   NRF1.H12CORE.0.PS.A
# 1    ...            0.969925     SP4.H12CORE.0.P.C
# 2    ...            0.937175  GMEB2.H12CORE.2.SM.B
# 3    ...            0.981210   ZN143.H12CORE.0.P.B
# 4    ...            0.978794    NFYA.H12CORE.0.P.B
# ..   ...                 ...                   ...
# 994  ...            0.912841  RFX1.H12CORE.1.PSM.A
# 995  ...            0.908444   CEBPD.H12CORE.0.P.B
# 996  ...            0.898491    MITF.H12CORE.0.P.B
# 997  ...            0.901590   RUNX2.H12CORE.0.P.B
# 998  ...            0.825721   FOSL1.H12CORE.0.P.B
#
#                                          hocomoco_logo num_patterns  \
# 0    =IMAGE("https://mitra.stanford.edu/kundaje/oak...           74
# 1    =IMAGE("https://mitra.stanford.edu/kundaje/oak...           58
# 2    =IMAGE("https://mitra.stanford.edu/kundaje/oak...           55
# 3    =IMAGE("https://mitra.stanford.edu/kundaje/oak...           54
# 4    =IMAGE("https://mitra.stanford.edu/kundaje/oak...           54
# ..                                                 ...          ...
# 994  =IMAGE("https://mitra.stanford.edu/kundaje/oak...            1
# 995  =IMAGE("https://mitra.stanford.edu/kundaje/oak...            1
# 996  =IMAGE("https://mitra.stanford.edu/kundaje/oak...            1
# 997  =IMAGE("https://mitra.stanford.edu/kundaje/oak...            1
# 998  =IMAGE("https://mitra.stanford.edu/kundaje/oak...            1
#
#     num_seqlets  num_samples  num_datasets  \
# 0        194827           53             3
# 1        372948           54             3
# 2        137965           53             3
# 3         92698           54             3
# 4        317250           54             3
# ..          ...          ...           ...
# 994          28            1             1
# 995          27            1             1
# 996          26            1             1
# 997          24            1             1
# 998          22            1             1
#
#                                  datasets  posneg index
# 0    corces_2020,domcke_2020,trevino_2021     pos     0
# 1    corces_2020,domcke_2020,trevino_2021     pos     1
# 2    corces_2020,domcke_2020,trevino_2021     pos     2
# 3    corces_2020,domcke_2020,trevino_2021     pos     3
# 4    corces_2020,domcke_2020,trevino_2021     pos     4
# ..                                    ...     ...   ...
# 994                           corces_2020     pos   994
# 995                           corces_2020     pos   995
# 996                           corces_2020     pos   996
# 997                           corces_2020     pos   997
# 998                           corces_2020     pos   998
#
# [999 rows x 22 columns]

# %%
metadata.to_csv('/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/leiden_96/neuro-variants.all_data.motif_compendium.avg.metadata.leiden_96.logos.tsv',
                sep='\t', index=False)
