# %%
import MotifCompendium
import MotifCompendium.utils.analysis as utils_analysis
import MotifCompendium.utils.motif as utils_motif
from MotifCompendium.utils.similarity import set_default_options
from IPython.display import display, HTML, Image
import pandas as pd
import numpy as np
import os
import h5py
import matplotlib.pyplot as plt
import seaborn as sns
from multiprocessing import Pool
import scipy.cluster.hierarchy as sch
from scipy.cluster.hierarchy import linkage, leaves_list, dendrogram

# %%
# Directory containing the data
data_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias'
table_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/tables'
rare_variants_file = '/oak/stanford/groups/akundaje/projects/neuro-variants/variant_lists/shap_variants.rare.model_inputs.hg38.tsv'
variant_motif_matrices_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/variant_motif_matrices/rare/K562_bias'
plot_dir = '/oak/stanford/groups/akundaje/projects/neuro-variants/plots/motifs'
motif_file_name = "hits_unique.tsv"

fold = 'mean'
score_type = 'counts'
alpha = 'alpha_0.8'
leiden = 'leiden_96'

# Define motifs to exclude
EXCLUDED_MOTIFS = ['ZBTB33', 'POU_4', 'SP-KLF_2', 'BCL11', 'BHLH::NFI_5',
                   'NHLH', 'BHLH_3', 'NFI-half_1', 'NFI-half_3', 'HAND',
                   'E2F_2', 'SOX::SOX_13', 'SOX::SOX_12', 'DLX']

# %%
mc = MotifCompendium.load('/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/'
                          + leiden + '/neuro-variants.all_data.motif_compendium.' + leiden + '.mc')

mc['original_pattern'] = mc['name'].str.split('-').str[1].str.split('.').str[0] + '_patterns.' + mc['name'].str.split('.').str[-1]
mc_metadata = mc.metadata.copy()
mc_metadata = mc_metadata[['model', 'original_pattern', leiden, 'annotation']]

mc_metadata
# Out:
#                       model         original_pattern  leiden_96  \
# 0          trevino_2021.c20   pos_patterns.pattern_0         10
# 1          trevino_2021.c20   pos_patterns.pattern_1          5
# 2          trevino_2021.c20  pos_patterns.pattern_10          2
# 3          trevino_2021.c20  pos_patterns.pattern_11          7
# 4          trevino_2021.c20  pos_patterns.pattern_12          3
# ...                     ...                      ...        ...
# 2483  corces_2020.Cluster24   pos_patterns.pattern_6         99
# 2484  corces_2020.Cluster24   pos_patterns.pattern_7          4
# 2485  corces_2020.Cluster24   pos_patterns.pattern_8         19
# 2486  corces_2020.Cluster24   pos_patterns.pattern_9         10
# 2487  corces_2020.Cluster24   neg_patterns.pattern_0         11
#
#                   annotation
# 0                   NFI-1_10
# 1                   CTCF-1_5
# 2          BZIP:ATF-CREB-1_2
# 3            ETS:ELF-ETV-1_7
# 4                 ZNF143-1_3
# ...                      ...
# 2483  IRF-STAT_IRF-STAT-1_99
# 2484                   NFY_4
# 2485      BZIP:ATF-CREB-1_19
# 2486                NFI-1_10
# 2487             ZEB-SNAI_11
#
# [2488 rows x 4 columns]

# %%
mc_avg = MotifCompendium.load('/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/'
                                + leiden + '/neuro-variants.all_data.motif_compendium.avg.' + leiden + '.mc')

mc_avg.metadata
# Out:
#      index                      name  num_patterns  num_seqlets  num_samples  \
# 0        0    pos_patterns.pattern_0            74       194827           53
# 1        1    pos_patterns.pattern_1            58       372948           54
# 2        2    pos_patterns.pattern_2            55       137965           53
# 3        3    pos_patterns.pattern_3            54        92698           54
# 4        4    pos_patterns.pattern_4            54       317250           54
# ..     ...                       ...           ...          ...          ...
# 994    994  pos_patterns.pattern_720             1           28            1
# 995    995  pos_patterns.pattern_721             1           27            1
# 996    996  pos_patterns.pattern_722             1           26            1
# 997    997  pos_patterns.pattern_723             1           24            1
# 998    998  pos_patterns.pattern_724             1           22            1
#
#      num_datasets                              datasets posneg  \
# 0               3  corces_2020,domcke_2020,trevino_2021    pos
# 1               3  corces_2020,domcke_2020,trevino_2021    pos
# 2               3  corces_2020,domcke_2020,trevino_2021    pos
# 3               3  corces_2020,domcke_2020,trevino_2021    pos
# 4               3  corces_2020,domcke_2020,trevino_2021    pos
# ..            ...                                   ...    ...
# 994             1                           corces_2020    pos
# 995             1                           corces_2020    pos
# 996             1                           corces_2020    pos
# 997             1                           corces_2020    pos
# 998             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 994             0.912841  RFX1.H12CORE.1.PSM.A             0.922637
# 995             0.908444   CEBPD.H12CORE.0.P.B             0.907553
# 996             0.898491    MITF.H12CORE.0.P.B             0.854161
# 997             0.901590   RUNX2.H12CORE.0.P.B             0.919790
# 998             0.825721   FOSL1.H12CORE.0.P.B             0.839746
#
#          vierstra_match  selin_similarity                     selin_match  \
# 0      NRF1_M09443_2.00          0.998523                            NRF1
# 1       SP4_M08296_2.00          0.998351                          SP/KLF
# 2     CREB1_M04258_2.00          0.998884                 BZIP:ATF/CREB#1
# 3      ETS1_M07950_2.00          0.999409                        ZNF143#1
# 4         NFYA_MA0060.1          0.999510                             NFY
# ..                  ...               ...                             ...
# 994    RFX2_M09362_2.00          0.962012                           RFX#1
# 995   CEBPA_M08813_2.00          0.930452                     BZIP:CEBP#1
# 996  ZNF317_M08308_2.00          0.888819                   BHLH:USF1/2#1
# 997   RUNX3_M02751_2.00          0.937730                          RUNX#1
# 998     JUN_M07837_2.00          0.875790  BZIP:FOSL/JUND_NR:ESRRA/NR5A#1
#
#             annotation
# 0               NRF1_0
# 1             SP-KLF_1
# 2    BZIP:ATF-CREB-1_2
# 3           ZNF143-1_3
# 4                NFY_4
# ..                 ...
# 994          RFX-1_994
# 995        Unknown_995
# 996        Unknown_996
# 997        Unknown_997
# 998        Unknown_998
#
# [999 rows x 15 columns]

# %%
# Define the entropy metrics we want to calculate
entropy_list = [
    "motif_entropy",
    "posbase_entropy_ratio",
    "copair_entropy_ratio",
    "dinuc_entropy_ratio"
]

# Calculate entropy metrics
utils_analysis.calculate_entropy(
    mc_avg,
    entropy_list=entropy_list
)

mc_avg.metadata.rename(columns={'index': leiden,
                                'name': 'clustered_pattern'},
                                inplace=True)

mc_avg.metadata
# Out:
#      leiden_96         clustered_pattern  num_patterns  num_seqlets  \
# 0            0    pos_patterns.pattern_0            74       194827
# 1            1    pos_patterns.pattern_1            58       372948
# 2            2    pos_patterns.pattern_2            55       137965
# 3            3    pos_patterns.pattern_3            54        92698
# 4            4    pos_patterns.pattern_4            54       317250
# ..         ...                       ...           ...          ...
# 994        994  pos_patterns.pattern_720             1           28
# 995        995  pos_patterns.pattern_721             1           27
# 996        996  pos_patterns.pattern_722             1           26
# 997        997  pos_patterns.pattern_723             1           24
# 998        998  pos_patterns.pattern_724             1           22
#
#      num_samples  num_datasets                              datasets posneg  \
# 0             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 1             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 2             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 3             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 4             54             3  corces_2020,domcke_2020,trevino_2021    pos
# ..           ...           ...                                   ...    ...
# 994            1             1                           corces_2020    pos
# 995            1             1                           corces_2020    pos
# 996            1             1                           corces_2020    pos
# 997            1             1                           corces_2020    pos
# 998            1             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 994             0.912841  RFX1.H12CORE.1.PSM.A             0.922637
# 995             0.908444   CEBPD.H12CORE.0.P.B             0.907553
# 996             0.898491    MITF.H12CORE.0.P.B             0.854161
# 997             0.901590   RUNX2.H12CORE.0.P.B             0.919790
# 998             0.825721   FOSL1.H12CORE.0.P.B             0.839746
#
#          vierstra_match  selin_similarity                     selin_match  \
# 0      NRF1_M09443_2.00          0.998523                            NRF1
# 1       SP4_M08296_2.00          0.998351                          SP/KLF
# 2     CREB1_M04258_2.00          0.998884                 BZIP:ATF/CREB#1
# 3      ETS1_M07950_2.00          0.999409                        ZNF143#1
# 4         NFYA_MA0060.1          0.999510                             NFY
# ..                  ...               ...                             ...
# 994    RFX2_M09362_2.00          0.962012                           RFX#1
# 995   CEBPA_M08813_2.00          0.930452                     BZIP:CEBP#1
# 996  ZNF317_M08308_2.00          0.888819                   BHLH:USF1/2#1
# 997   RUNX3_M02751_2.00          0.937730                          RUNX#1
# 998     JUN_M07837_2.00          0.875790  BZIP:FOSL/JUND_NR:ESRRA/NR5A#1
#
#             annotation  posbase_entropy_ratio  motif_entropy  \
# 0               NRF1_0               1.543807       0.516517
# 1             SP-KLF_1               2.061026       0.510798
# 2    BZIP:ATF-CREB-1_2               1.127238       0.506504
# 3           ZNF143-1_3               1.445198       0.567049
# 4                NFY_4               1.144037       0.487531
# ..                 ...                    ...            ...
# 994          RFX-1_994               1.284123       0.572708
# 995        Unknown_995               1.223956       0.540519
# 996        Unknown_996               1.137544       0.560141
# 997        Unknown_997               1.522029       0.577830
# 998        Unknown_998               1.242215       0.550643
#
#      dinuc_entropy_ratio  copair_entropy_ratio
# 0               2.845492              1.488471
# 1               1.740413              1.639470
# 2               1.292231              1.554268
# 3               1.474322              1.301145
# 4               1.526165              1.653990
# ..                   ...                   ...
# 994             1.447394              1.632554
# 995             1.552044              1.222717
# 996             1.442505              1.232628
# 997             1.518736              1.494380
# 998             1.725007              1.295704
#
# [999 rows x 19 columns]

# %%
mc_avg_metadata = mc_avg.metadata.copy()

mc_avg_metadata
# Out:
#      leiden_96         clustered_pattern  num_patterns  num_seqlets  \
# 0            0    pos_patterns.pattern_0            74       194827
# 1            1    pos_patterns.pattern_1            58       372948
# 2            2    pos_patterns.pattern_2            55       137965
# 3            3    pos_patterns.pattern_3            54        92698
# 4            4    pos_patterns.pattern_4            54       317250
# ..         ...                       ...           ...          ...
# 994        994  pos_patterns.pattern_720             1           28
# 995        995  pos_patterns.pattern_721             1           27
# 996        996  pos_patterns.pattern_722             1           26
# 997        997  pos_patterns.pattern_723             1           24
# 998        998  pos_patterns.pattern_724             1           22
#
#      num_samples  num_datasets                              datasets posneg  \
# 0             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 1             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 2             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 3             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 4             54             3  corces_2020,domcke_2020,trevino_2021    pos
# ..           ...           ...                                   ...    ...
# 994            1             1                           corces_2020    pos
# 995            1             1                           corces_2020    pos
# 996            1             1                           corces_2020    pos
# 997            1             1                           corces_2020    pos
# 998            1             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 994             0.912841  RFX1.H12CORE.1.PSM.A             0.922637
# 995             0.908444   CEBPD.H12CORE.0.P.B             0.907553
# 996             0.898491    MITF.H12CORE.0.P.B             0.854161
# 997             0.901590   RUNX2.H12CORE.0.P.B             0.919790
# 998             0.825721   FOSL1.H12CORE.0.P.B             0.839746
#
#          vierstra_match  selin_similarity                     selin_match  \
# 0      NRF1_M09443_2.00          0.998523                            NRF1
# 1       SP4_M08296_2.00          0.998351                          SP/KLF
# 2     CREB1_M04258_2.00          0.998884                 BZIP:ATF/CREB#1
# 3      ETS1_M07950_2.00          0.999409                        ZNF143#1
# 4         NFYA_MA0060.1          0.999510                             NFY
# ..                  ...               ...                             ...
# 994    RFX2_M09362_2.00          0.962012                           RFX#1
# 995   CEBPA_M08813_2.00          0.930452                     BZIP:CEBP#1
# 996  ZNF317_M08308_2.00          0.888819                   BHLH:USF1/2#1
# 997   RUNX3_M02751_2.00          0.937730                          RUNX#1
# 998     JUN_M07837_2.00          0.875790  BZIP:FOSL/JUND_NR:ESRRA/NR5A#1
#
#             annotation  posbase_entropy_ratio  motif_entropy  \
# 0               NRF1_0               1.543807       0.516517
# 1             SP-KLF_1               2.061026       0.510798
# 2    BZIP:ATF-CREB-1_2               1.127238       0.506504
# 3           ZNF143-1_3               1.445198       0.567049
# 4                NFY_4               1.144037       0.487531
# ..                 ...                    ...            ...
# 994          RFX-1_994               1.284123       0.572708
# 995        Unknown_995               1.223956       0.540519
# 996        Unknown_996               1.137544       0.560141
# 997        Unknown_997               1.522029       0.577830
# 998        Unknown_998               1.242215       0.550643
#
#      dinuc_entropy_ratio  copair_entropy_ratio
# 0               2.845492              1.488471
# 1               1.740413              1.639470
# 2               1.292231              1.554268
# 3               1.474322              1.301145
# 4               1.526165              1.653990
# ..                   ...                   ...
# 994             1.447394              1.632554
# 995             1.552044              1.222717
# 996             1.442505              1.232628
# 997             1.518736              1.494380
# 998             1.725007              1.295704
#
# [999 rows x 19 columns]

# %%
mc_avg_metadata.columns
# Out:
# Index(['leiden_96', 'clustered_pattern', 'num_patterns', 'num_seqlets',
#        'num_samples', 'num_datasets', 'datasets', 'posneg',
#        'hocomoco_similarity', 'hocomoco_match', 'vierstra_similarity',
#        'vierstra_match', 'selin_similarity', 'selin_match', 'annotation',
#        'posbase_entropy_ratio', 'motif_entropy', 'dinuc_entropy_ratio',
#        'copair_entropy_ratio'],
#       dtype='object')

# %%
manual_annotations = pd.read_table('/oak/stanford/groups/akundaje/projects/neuro-variants/motif_compendium/all_data/'
                                    + leiden + '/neuro-variants.all_data.motif_compendium.avg.metadata.annotated_only.manual.including_repeats.'
                                    + leiden + '.tsv',
                                    names=['clustered_pattern', 'manual_annotation'])

manual_annotations
# Out:
#             clustered_pattern   manual_annotation
# 0     pos_patterns.pattern_18                 AP1
# 1    pos_patterns.pattern_276           AP1::NFAT
# 2     pos_patterns.pattern_17            ARNT-USF
# 3    pos_patterns.pattern_149         AT-repeat_1
# 4    neg_patterns.pattern_246         AT-repeat_2
# ..                        ...                 ...
# 185   neg_patterns.pattern_11               ZBTB7
# 186    neg_patterns.pattern_0            ZEB-SNAI
# 187    neg_patterns.pattern_3  ZEB-SNAI::ZEB-SNAI
# 188    pos_patterns.pattern_3            ZNF143_1
# 189   pos_patterns.pattern_13            ZNF143_2
#
# [190 rows x 2 columns]

# %%
mc_avg_manual_annotations = mc_avg_metadata.merge(manual_annotations, on=['clustered_pattern'], how='left')

mc_avg_manual_annotations
# Out:
#      leiden_96         clustered_pattern  num_patterns  num_seqlets  \
# 0            0    pos_patterns.pattern_0            74       194827
# 1            1    pos_patterns.pattern_1            58       372948
# 2            2    pos_patterns.pattern_2            55       137965
# 3            3    pos_patterns.pattern_3            54        92698
# 4            4    pos_patterns.pattern_4            54       317250
# ..         ...                       ...           ...          ...
# 994        994  pos_patterns.pattern_720             1           28
# 995        995  pos_patterns.pattern_721             1           27
# 996        996  pos_patterns.pattern_722             1           26
# 997        997  pos_patterns.pattern_723             1           24
# 998        998  pos_patterns.pattern_724             1           22
#
#      num_samples  num_datasets                              datasets posneg  \
# 0             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 1             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 2             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 3             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 4             54             3  corces_2020,domcke_2020,trevino_2021    pos
# ..           ...           ...                                   ...    ...
# 994            1             1                           corces_2020    pos
# 995            1             1                           corces_2020    pos
# 996            1             1                           corces_2020    pos
# 997            1             1                           corces_2020    pos
# 998            1             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 994             0.912841  RFX1.H12CORE.1.PSM.A             0.922637
# 995             0.908444   CEBPD.H12CORE.0.P.B             0.907553
# 996             0.898491    MITF.H12CORE.0.P.B             0.854161
# 997             0.901590   RUNX2.H12CORE.0.P.B             0.919790
# 998             0.825721   FOSL1.H12CORE.0.P.B             0.839746
#
#          vierstra_match  selin_similarity                     selin_match  \
# 0      NRF1_M09443_2.00          0.998523                            NRF1
# 1       SP4_M08296_2.00          0.998351                          SP/KLF
# 2     CREB1_M04258_2.00          0.998884                 BZIP:ATF/CREB#1
# 3      ETS1_M07950_2.00          0.999409                        ZNF143#1
# 4         NFYA_MA0060.1          0.999510                             NFY
# ..                  ...               ...                             ...
# 994    RFX2_M09362_2.00          0.962012                           RFX#1
# 995   CEBPA_M08813_2.00          0.930452                     BZIP:CEBP#1
# 996  ZNF317_M08308_2.00          0.888819                   BHLH:USF1/2#1
# 997   RUNX3_M02751_2.00          0.937730                          RUNX#1
# 998     JUN_M07837_2.00          0.875790  BZIP:FOSL/JUND_NR:ESRRA/NR5A#1
#
#             annotation  posbase_entropy_ratio  motif_entropy  \
# 0               NRF1_0               1.543807       0.516517
# 1             SP-KLF_1               2.061026       0.510798
# 2    BZIP:ATF-CREB-1_2               1.127238       0.506504
# 3           ZNF143-1_3               1.445198       0.567049
# 4                NFY_4               1.144037       0.487531
# ..                 ...                    ...            ...
# 994          RFX-1_994               1.284123       0.572708
# 995        Unknown_995               1.223956       0.540519
# 996        Unknown_996               1.137544       0.560141
# 997        Unknown_997               1.522029       0.577830
# 998        Unknown_998               1.242215       0.550643
#
#      dinuc_entropy_ratio  copair_entropy_ratio manual_annotation
# 0               2.845492              1.488471              NRF1
# 1               1.740413              1.639470          SP-KLF_1
# 2               1.292231              1.554268             ATF_1
# 3               1.474322              1.301145          ZNF143_1
# 4               1.526165              1.653990               NFY
# ..                   ...                   ...               ...
# 994             1.447394              1.632554               NaN
# 995             1.552044              1.222717               NaN
# 996             1.442505              1.232628               NaN
# 997             1.518736              1.494380               NaN
# 998             1.725007              1.295704               NaN
#
# [999 rows x 20 columns]

# %%
mc_avg_manual_annotations.columns
# Out:
# Index(['leiden_96', 'clustered_pattern', 'num_patterns', 'num_seqlets',
#        'num_samples', 'num_datasets', 'datasets', 'posneg',
#        'hocomoco_similarity', 'hocomoco_match', 'vierstra_similarity',
#        'vierstra_match', 'selin_similarity', 'selin_match', 'annotation',
#        'posbase_entropy_ratio', 'motif_entropy', 'dinuc_entropy_ratio',
#        'copair_entropy_ratio', 'manual_annotation'],
#       dtype='object')

# %%
mc_manual_annotations = mc_metadata.merge(mc_avg_manual_annotations, on=[leiden, 'annotation'], how='left')

mc_manual_annotations
# Out:
#                       model         original_pattern  leiden_96  \
# 0          trevino_2021.c20   pos_patterns.pattern_0         10
# 1          trevino_2021.c20   pos_patterns.pattern_1          5
# 2          trevino_2021.c20  pos_patterns.pattern_10          2
# 3          trevino_2021.c20  pos_patterns.pattern_11          7
# 4          trevino_2021.c20  pos_patterns.pattern_12          3
# ...                     ...                      ...        ...
# 2483  corces_2020.Cluster24   pos_patterns.pattern_6         99
# 2484  corces_2020.Cluster24   pos_patterns.pattern_7          4
# 2485  corces_2020.Cluster24   pos_patterns.pattern_8         19
# 2486  corces_2020.Cluster24   pos_patterns.pattern_9         10
# 2487  corces_2020.Cluster24   neg_patterns.pattern_0         11
#
#                   annotation        clustered_pattern  num_patterns  \
# 0                   NFI-1_10  pos_patterns.pattern_10            47
# 1                   CTCF-1_5   pos_patterns.pattern_5            54
# 2          BZIP:ATF-CREB-1_2   pos_patterns.pattern_2            55
# 3            ETS:ELF-ETV-1_7   pos_patterns.pattern_7            53
# 4                 ZNF143-1_3   pos_patterns.pattern_3            54
# ...                      ...                      ...           ...
# 2483  IRF-STAT_IRF-STAT-1_99  pos_patterns.pattern_83             2
# 2484                   NFY_4   pos_patterns.pattern_4            54
# 2485      BZIP:ATF-CREB-1_19  pos_patterns.pattern_17            29
# 2486                NFI-1_10  pos_patterns.pattern_10            47
# 2487             ZEB-SNAI_11   neg_patterns.pattern_0            45
#
#       num_seqlets  num_samples  num_datasets  \
# 0          537160           47             3
# 1          947567           54             3
# 2          137965           53             3
# 3          163362           52             3
# 4           92698           54             3
# ...           ...          ...           ...
# 2483         6758            2             2
# 2484       317250           54             3
# 2485        32724           28             3
# 2486       537160           47             3
# 2487        64734           42             3
#
#                                   datasets  ...         hocomoco_match  \
# 0     corces_2020,domcke_2020,trevino_2021  ...    NFIX.H12CORE.0.SM.B
# 1     corces_2020,domcke_2020,trevino_2021  ...     CTCF.H12CORE.0.P.B
# 2     corces_2020,domcke_2020,trevino_2021  ...   GMEB2.H12CORE.2.SM.B
# 3     corces_2020,domcke_2020,trevino_2021  ...   ELK4.H12CORE.0.PSM.A
# 4     corces_2020,domcke_2020,trevino_2021  ...    ZN143.H12CORE.0.P.B
# ...                                    ...  ...                    ...
# 2483              corces_2020,trevino_2021  ...    IRF3.H12CORE.0.PS.A
# 2484  corces_2020,domcke_2020,trevino_2021  ...     NFYA.H12CORE.0.P.B
# 2485  corces_2020,domcke_2020,trevino_2021  ...  BHE41.H12CORE.0.PSM.A
# 2486  corces_2020,domcke_2020,trevino_2021  ...    NFIX.H12CORE.0.SM.B
# 2487  corces_2020,domcke_2020,trevino_2021  ...     ZEB2.H12CORE.0.P.B
#
#       vierstra_similarity       vierstra_match  selin_similarity  \
# 0                0.964340     NFIC_M09636_2.00          0.999624
# 1                0.983484    CTCFL_M09507_2.00          0.999548
# 2                0.973756    CREB1_M04258_2.00          0.998884
# 3                0.956144     ELK3_M04730_2.00          0.999409
# 4                0.971501     ETS1_M07950_2.00          0.999409
# ...                   ...                  ...               ...
# 2483             0.934069    STAT1_M08230_2.00          0.989269
# 2484             0.984840        NFYA_MA0060.1          0.999510
# 2485             0.984382  BHLHE41_M02783_2.00          0.997725
# 2486             0.964340     NFIC_M09636_2.00          0.999624
# 2487             0.973456     ZEB1_M10093_2.00          0.998706
#
#               selin_match  posbase_entropy_ratio motif_entropy  \
# 0                   NFI#1               1.253310      0.466839
# 1                  CTCF#1               1.413051      0.530499
# 2         BZIP:ATF/CREB#1               1.127238      0.506504
# 3           ETS:ELF/ETV#1               1.272438      0.488163
# 4                ZNF143#1               1.445198      0.567049
# ...                   ...                    ...           ...
# 2483  IRF/STAT_IRF/STAT#1               1.423037      0.509113
# 2484                  NFY               1.144037      0.487531
# 2485      BZIP:ATF/CREB#1               1.158009      0.504458
# 2486                NFI#1               1.253310      0.466839
# 2487             ZEB/SNAI               0.975639      0.385345
#
#       dinuc_entropy_ratio  copair_entropy_ratio  manual_annotation
# 0                1.401777              1.142712              NFI_1
# 1                1.424199              1.240325             CTCF_1
# 2                1.292231              1.554268              ATF_1
# 3                1.458882              1.557328              ETS_2
# 4                1.474322              1.301145           ZNF143_1
# ...                   ...                   ...                ...
# 2483             1.896891              1.408563              IRF_2
# 2484             1.526165              1.653990                NFY
# 2485             1.425264              1.851094           ARNT-USF
# 2486             1.401777              1.142712              NFI_1
# 2487             1.493655              1.187869           ZEB-SNAI
#
# [2488 rows x 22 columns]

# %%
# Filter out motifs that have nan manual annotations
mc_manual_annotations_filtered = mc_manual_annotations.loc[~mc_manual_annotations['manual_annotation'].isna()].copy()

mc_manual_annotations_filtered = mc_manual_annotations_filtered.loc[(~mc_manual_annotations_filtered['manual_annotation'].str.startswith('Unknown')) &
                                                                    (~mc_manual_annotations_filtered['manual_annotation'].str.contains('repeat'))]

mc_manual_annotations_filtered
# Out:
#                       model         original_pattern  leiden_96  \
# 0          trevino_2021.c20   pos_patterns.pattern_0         10
# 1          trevino_2021.c20   pos_patterns.pattern_1          5
# 2          trevino_2021.c20  pos_patterns.pattern_10          2
# 3          trevino_2021.c20  pos_patterns.pattern_11          7
# 4          trevino_2021.c20  pos_patterns.pattern_12          3
# ...                     ...                      ...        ...
# 2483  corces_2020.Cluster24   pos_patterns.pattern_6         99
# 2484  corces_2020.Cluster24   pos_patterns.pattern_7          4
# 2485  corces_2020.Cluster24   pos_patterns.pattern_8         19
# 2486  corces_2020.Cluster24   pos_patterns.pattern_9         10
# 2487  corces_2020.Cluster24   neg_patterns.pattern_0         11
#
#                   annotation        clustered_pattern  num_patterns  \
# 0                   NFI-1_10  pos_patterns.pattern_10            47
# 1                   CTCF-1_5   pos_patterns.pattern_5            54
# 2          BZIP:ATF-CREB-1_2   pos_patterns.pattern_2            55
# 3            ETS:ELF-ETV-1_7   pos_patterns.pattern_7            53
# 4                 ZNF143-1_3   pos_patterns.pattern_3            54
# ...                      ...                      ...           ...
# 2483  IRF-STAT_IRF-STAT-1_99  pos_patterns.pattern_83             2
# 2484                   NFY_4   pos_patterns.pattern_4            54
# 2485      BZIP:ATF-CREB-1_19  pos_patterns.pattern_17            29
# 2486                NFI-1_10  pos_patterns.pattern_10            47
# 2487             ZEB-SNAI_11   neg_patterns.pattern_0            45
#
#       num_seqlets  num_samples  num_datasets  \
# 0          537160           47             3
# 1          947567           54             3
# 2          137965           53             3
# 3          163362           52             3
# 4           92698           54             3
# ...           ...          ...           ...
# 2483         6758            2             2
# 2484       317250           54             3
# 2485        32724           28             3
# 2486       537160           47             3
# 2487        64734           42             3
#
#                                   datasets  ...         hocomoco_match  \
# 0     corces_2020,domcke_2020,trevino_2021  ...    NFIX.H12CORE.0.SM.B
# 1     corces_2020,domcke_2020,trevino_2021  ...     CTCF.H12CORE.0.P.B
# 2     corces_2020,domcke_2020,trevino_2021  ...   GMEB2.H12CORE.2.SM.B
# 3     corces_2020,domcke_2020,trevino_2021  ...   ELK4.H12CORE.0.PSM.A
# 4     corces_2020,domcke_2020,trevino_2021  ...    ZN143.H12CORE.0.P.B
# ...                                    ...  ...                    ...
# 2483              corces_2020,trevino_2021  ...    IRF3.H12CORE.0.PS.A
# 2484  corces_2020,domcke_2020,trevino_2021  ...     NFYA.H12CORE.0.P.B
# 2485  corces_2020,domcke_2020,trevino_2021  ...  BHE41.H12CORE.0.PSM.A
# 2486  corces_2020,domcke_2020,trevino_2021  ...    NFIX.H12CORE.0.SM.B
# 2487  corces_2020,domcke_2020,trevino_2021  ...     ZEB2.H12CORE.0.P.B
#
#       vierstra_similarity       vierstra_match  selin_similarity  \
# 0                0.964340     NFIC_M09636_2.00          0.999624
# 1                0.983484    CTCFL_M09507_2.00          0.999548
# 2                0.973756    CREB1_M04258_2.00          0.998884
# 3                0.956144     ELK3_M04730_2.00          0.999409
# 4                0.971501     ETS1_M07950_2.00          0.999409
# ...                   ...                  ...               ...
# 2483             0.934069    STAT1_M08230_2.00          0.989269
# 2484             0.984840        NFYA_MA0060.1          0.999510
# 2485             0.984382  BHLHE41_M02783_2.00          0.997725
# 2486             0.964340     NFIC_M09636_2.00          0.999624
# 2487             0.973456     ZEB1_M10093_2.00          0.998706
#
#               selin_match  posbase_entropy_ratio motif_entropy  \
# 0                   NFI#1               1.253310      0.466839
# 1                  CTCF#1               1.413051      0.530499
# 2         BZIP:ATF/CREB#1               1.127238      0.506504
# 3           ETS:ELF/ETV#1               1.272438      0.488163
# 4                ZNF143#1               1.445198      0.567049
# ...                   ...                    ...           ...
# 2483  IRF/STAT_IRF/STAT#1               1.423037      0.509113
# 2484                  NFY               1.144037      0.487531
# 2485      BZIP:ATF/CREB#1               1.158009      0.504458
# 2486                NFI#1               1.253310      0.466839
# 2487             ZEB/SNAI               0.975639      0.385345
#
#       dinuc_entropy_ratio  copair_entropy_ratio  manual_annotation
# 0                1.401777              1.142712              NFI_1
# 1                1.424199              1.240325             CTCF_1
# 2                1.292231              1.554268              ATF_1
# 3                1.458882              1.557328              ETS_2
# 4                1.474322              1.301145           ZNF143_1
# ...                   ...                   ...                ...
# 2483             1.896891              1.408563              IRF_2
# 2484             1.526165              1.653990                NFY
# 2485             1.425264              1.851094           ARNT-USF
# 2486             1.401777              1.142712              NFI_1
# 2487             1.493655              1.187869           ZEB-SNAI
#
# [1431 rows x 22 columns]

# %%
mc_manual_annotations_filtered['manual_annotation'].nunique()
# Out:
# 155

# %%
# Filter out motifs that have nan manual annotations
mc_avg_manual_annotations_filtered = mc_avg_manual_annotations.loc[~mc_avg_manual_annotations['manual_annotation'].isna()].copy()

mc_avg_manual_annotations_filtered = mc_avg_manual_annotations_filtered.loc[(~mc_avg_manual_annotations_filtered['manual_annotation'].str.startswith('Unknown')) &
                                                                            (~mc_avg_manual_annotations_filtered['manual_annotation'].str.contains('repeat'))]

mc_avg_manual_annotations_filtered
# Out:
#      leiden_96         clustered_pattern  num_patterns  num_seqlets  \
# 0            0    pos_patterns.pattern_0            74       194827
# 1            1    pos_patterns.pattern_1            58       372948
# 2            2    pos_patterns.pattern_2            55       137965
# 3            3    pos_patterns.pattern_3            54        92698
# 4            4    pos_patterns.pattern_4            54       317250
# ..         ...                       ...           ...          ...
# 942        942  pos_patterns.pattern_680             1         1230
# 943        943  pos_patterns.pattern_681             1         1165
# 968        968  pos_patterns.pattern_694             1         3789
# 969        969  pos_patterns.pattern_695             1         3293
# 970        970  pos_patterns.pattern_696             1         1431
#
#      num_samples  num_datasets                              datasets posneg  \
# 0             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 1             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 2             53             3  corces_2020,domcke_2020,trevino_2021    pos
# 3             54             3  corces_2020,domcke_2020,trevino_2021    pos
# 4             54             3  corces_2020,domcke_2020,trevino_2021    pos
# ..           ...           ...                                   ...    ...
# 942            1             1                           corces_2020    pos
# 943            1             1                           corces_2020    pos
# 968            1             1                           corces_2020    pos
# 969            1             1                           corces_2020    pos
# 970            1             1                           corces_2020    pos
#
#      hocomoco_similarity        hocomoco_match  vierstra_similarity  \
# 0               0.914414   NRF1.H12CORE.0.PS.A             0.951238
# 1               0.969925     SP4.H12CORE.0.P.C             0.944662
# 2               0.937175  GMEB2.H12CORE.2.SM.B             0.973756
# 3               0.981210   ZN143.H12CORE.0.P.B             0.971501
# 4               0.978794    NFYA.H12CORE.0.P.B             0.984840
# ..                   ...                   ...                  ...
# 942             0.975248  PO2F3.H12CORE.0.PS.A             0.883825
# 943             0.834702   HME2.H12CORE.0.SM.B             0.854191
# 968             0.969082   RUNX2.H12CORE.0.P.B             0.982315
# 969             0.893427    ETV6.H12CORE.1.P.B             0.948562
# 970             0.942974  MAFG.H12CORE.1.PSM.A             0.929127
#
#         vierstra_match  selin_similarity                    selin_match  \
# 0     NRF1_M09443_2.00          0.998523                           NRF1
# 1      SP4_M08296_2.00          0.998351                         SP/KLF
# 2    CREB1_M04258_2.00          0.998884                BZIP:ATF/CREB#1
# 3     ETS1_M07950_2.00          0.999409                       ZNF143#1
# 4        NFYA_MA0060.1          0.999510                            NFY
# ..                 ...               ...                            ...
# 942   VSX2_M05039_2.00          0.957176                           HD#1
# 943  LMX1B_M05154_2.00          0.867289                           HD#1
# 968  RUNX3_M09369_2.00          0.994932                         RUNX#1
# 969   ETV4_M04798_2.00          0.991183                 ETS:ELF/SPIB#1
# 970   MAFA_M04356_2.00          0.975047  BZIP:MAFG/MAFF_BZIP:MAFG/MAFF
#
#                             annotation  posbase_entropy_ratio  motif_entropy  \
# 0                               NRF1_0               1.543807       0.516517
# 1                             SP-KLF_1               2.061026       0.510798
# 2                    BZIP:ATF-CREB-1_2               1.127238       0.506504
# 3                           ZNF143-1_3               1.445198       0.567049
# 4                                NFY_4               1.144037       0.487531
# ..                                 ...                    ...            ...
# 942           PO2F3.H12CORE.0.PS.A_942               1.069282       0.486243
# 943                        Unknown_943               1.114464       0.502105
# 968                         RUNX-1_968               1.562398       0.501254
# 969                 ETS:ELF-SPIB-1_969               1.728998       0.499603
# 970  BZIP:MAFG-MAFF_BZIP:MAFG-MAFF_970               1.275544       0.553824
#
#      dinuc_entropy_ratio  copair_entropy_ratio manual_annotation
# 0               2.845492              1.488471              NRF1
# 1               1.740413              1.639470          SP-KLF_1
# 2               1.292231              1.554268             ATF_1
# 3               1.474322              1.301145          ZNF143_1
# 4               1.526165              1.653990               NFY
# ..                   ...                   ...               ...
# 942             1.177785              1.375409             LHX_2
# 943             1.168189              1.296962           POU4F_1
# 968             1.741838              1.853814              RUNX
# 969             2.168055              1.546192             ETV_1
# 970             1.401184              1.543896               MAF
#
# [155 rows x 20 columns]

# %%
mc_avg_manual_annotations_filtered['manual_annotation'].nunique()
# Out:
# 155

# %%
original_pattern_to_cluster = { (row['model'], row['original_pattern']): row['manual_annotation'] for _, row in mc_manual_annotations_filtered.iterrows() }

original_pattern_to_cluster
# Out:
# {('trevino_2021.c20', 'pos_patterns.pattern_0'): 'NFI_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_10'): 'ATF_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_11'): 'ETS_2',
#  ('trevino_2021.c20', 'pos_patterns.pattern_12'): 'ZNF143_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_13'): 'POU_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_14'): 'POU2F_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_15'): 'YY1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_16'): 'POU4F_2',
#  ('trevino_2021.c20', 'pos_patterns.pattern_17'): 'SP-KLF_2',
#  ('trevino_2021.c20', 'pos_patterns.pattern_18'): 'ZBTB33',
#  ('trevino_2021.c20', 'pos_patterns.pattern_19'): 'LHX::LHX_4',
#  ('trevino_2021.c20', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_20'): 'ETS::ATF_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_21'): 'ZBTB33',
#  ('trevino_2021.c20', 'pos_patterns.pattern_22'): 'RFX_2',
#  ('trevino_2021.c20', 'pos_patterns.pattern_24'): 'LHX::LHX_2',
#  ('trevino_2021.c20', 'pos_patterns.pattern_25'): 'BHLH::NFI_4',
#  ('trevino_2021.c20', 'pos_patterns.pattern_27'): 'ETS::SP-KLF',
#  ('trevino_2021.c20', 'pos_patterns.pattern_3'): 'NDF-ATOH_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_4'): 'NFY',
#  ('trevino_2021.c20', 'pos_patterns.pattern_5'): 'LHX_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_6'): 'SP-KLF_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_7'): 'BHLH_1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_8'): 'NRF1',
#  ('trevino_2021.c20', 'pos_patterns.pattern_9'): 'RFX_1',
#  ('trevino_2021.c20', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c20', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c20', 'neg_patterns.pattern_5'): 'BCL11',
#  ('trevino_2021.c19', 'pos_patterns.pattern_0'): 'ETS_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_10'): 'ZNF143_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_11'): 'ARNT-USF',
#  ('trevino_2021.c19', 'pos_patterns.pattern_12'): 'HLF',
#  ('trevino_2021.c19', 'pos_patterns.pattern_13'): 'IRF_2',
#  ('trevino_2021.c19', 'pos_patterns.pattern_14'): 'ARNT-USF',
#  ('trevino_2021.c19', 'pos_patterns.pattern_15'): 'ZBTB33',
#  ('trevino_2021.c19', 'pos_patterns.pattern_16'): 'IRF_3',
#  ('trevino_2021.c19', 'pos_patterns.pattern_18'): 'YY1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_19'): 'NFI_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_2'): 'ETS_2',
#  ('trevino_2021.c19', 'pos_patterns.pattern_20'): 'SP-KLF_3',
#  ('trevino_2021.c19', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_4'): 'AP1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_5'): 'IRF_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c19', 'pos_patterns.pattern_7'): 'NRF1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_8'): 'ATF_1',
#  ('trevino_2021.c19', 'pos_patterns.pattern_9'): 'CEBP_1',
#  ('trevino_2021.c19', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c19', 'neg_patterns.pattern_2'): 'ZEB-SNAI',
#  ('trevino_2021.c9', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_1'): 'NFI_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_11'): 'ATF_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_12'): 'RFX_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_13'): 'ATF_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_14'): 'ETS_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_15'): 'SOX::SOX_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_16'): 'ZNF143_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_17'): 'POU_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_18'): 'POU_5',
#  ('trevino_2021.c9', 'pos_patterns.pattern_19'): 'HESX1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_20'): 'BHLH::NFI_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_21'): 'POU2F_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_22'): 'ARNT-USF',
#  ('trevino_2021.c9', 'pos_patterns.pattern_23'): 'ETS::ATF_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_24'): 'YY1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_25'): 'ZBTB33',
#  ('trevino_2021.c9', 'pos_patterns.pattern_27'): 'NFI_8',
#  ('trevino_2021.c9', 'pos_patterns.pattern_28'): 'ETS::ETS_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_3'): 'LHX_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_32'): 'NFI_7',
#  ('trevino_2021.c9', 'pos_patterns.pattern_33'): 'ZNF143_2',
#  ('trevino_2021.c9', 'pos_patterns.pattern_4'): 'RFX_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_5'): 'AP1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_6'): 'SOX::SOX_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_7'): 'NFY',
#  ('trevino_2021.c9', 'pos_patterns.pattern_8'): 'SP-KLF_1',
#  ('trevino_2021.c9', 'pos_patterns.pattern_9'): 'POU_1',
#  ('trevino_2021.c9', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c9', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c16', 'pos_patterns.pattern_0'): 'BHLH_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_10'): 'POU_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_11'): 'ZNF143_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_13'): 'YY1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_14'): 'ZBTB33',
#  ('trevino_2021.c16', 'pos_patterns.pattern_15'): 'NRF1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_16'): 'POU2F_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_17'): 'LHX::LHX_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_18'): 'LHX::LHX_2',
#  ('trevino_2021.c16', 'pos_patterns.pattern_2'): 'LHX_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_20'): 'ETS::ATF_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_22'): 'RFX_2',
#  ('trevino_2021.c16', 'pos_patterns.pattern_25'): 'ZBTB33',
#  ('trevino_2021.c16', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_30'): 'ZNF143_2',
#  ('trevino_2021.c16', 'pos_patterns.pattern_31'): 'LHX::LHX_3',
#  ('trevino_2021.c16', 'pos_patterns.pattern_32'): 'ATF_2',
#  ('trevino_2021.c16', 'pos_patterns.pattern_33'): 'ETS::SP-KLF',
#  ('trevino_2021.c16', 'pos_patterns.pattern_4'): 'NFY',
#  ('trevino_2021.c16', 'pos_patterns.pattern_5'): 'NFI_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_6'): 'ATF_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_7'): 'ETS_2',
#  ('trevino_2021.c16', 'pos_patterns.pattern_8'): 'RFX_1',
#  ('trevino_2021.c16', 'pos_patterns.pattern_9'): 'NRF1',
#  ('trevino_2021.c16', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c16', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c4', 'pos_patterns.pattern_0'): 'BHLH_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_1'): 'LHX_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_10'): 'POU_2',
#  ('trevino_2021.c4', 'pos_patterns.pattern_11'): 'SP-KLF_2',
#  ('trevino_2021.c4', 'pos_patterns.pattern_12'): 'ATF_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_14'): 'SOX::SOX_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_15'): 'POU_4',
#  ('trevino_2021.c4', 'pos_patterns.pattern_17'): 'YY1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_18'): 'POU2F_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_19'): 'ARNT-USF',
#  ('trevino_2021.c4', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_20'): 'ZBTB33',
#  ('trevino_2021.c4', 'pos_patterns.pattern_21'): 'LHX::LHX_5',
#  ('trevino_2021.c4', 'pos_patterns.pattern_22'): 'ETS::ATF_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_23'): 'RFX_2',
#  ('trevino_2021.c4', 'pos_patterns.pattern_25'): 'ZNF143_2',
#  ('trevino_2021.c4', 'pos_patterns.pattern_29'): 'ETS::SP-KLF',
#  ('trevino_2021.c4', 'pos_patterns.pattern_3'): 'POU_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_4'): 'SP-KLF_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_5'): 'NFY',
#  ('trevino_2021.c4', 'pos_patterns.pattern_6'): 'NRF1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_7'): 'NFI_1',
#  ('trevino_2021.c4', 'pos_patterns.pattern_8'): 'ETS_2',
#  ('trevino_2021.c4', 'pos_patterns.pattern_9'): 'RFX_1',
#  ('trevino_2021.c4', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c4', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c4', 'neg_patterns.pattern_2'): 'BCL11',
#  ('trevino_2021.c1', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_1'): 'NDF-ATOH_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_10'): 'POU_3',
#  ('trevino_2021.c1', 'pos_patterns.pattern_11'): 'POU2F_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_12'): 'NRF1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_13'): 'BHLH::NFI_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_14'): 'ZNF143_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_15'): 'ETS_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_16'): 'ATF_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_17'): 'POU::POU',
#  ('trevino_2021.c1', 'pos_patterns.pattern_18'): 'SOX::POU_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_19'): 'NFI_6',
#  ('trevino_2021.c1', 'pos_patterns.pattern_2'): 'NFI_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_20'): 'YY1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_21'): 'RFX_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_22'): 'HESX1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_23'): 'TBR1_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_24'): 'LHX::LHX_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_25'): 'SP-KLF_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_26'): 'NFI::NDF-ATOH',
#  ('trevino_2021.c1', 'pos_patterns.pattern_27'): 'ETS::ATF_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_28'): 'ARNT-USF',
#  ('trevino_2021.c1', 'pos_patterns.pattern_29'): 'ZBTB33',
#  ('trevino_2021.c1', 'pos_patterns.pattern_3'): 'CTCF_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_32'): 'ETS::ETS_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_33'): 'LHX::NFI',
#  ('trevino_2021.c1', 'pos_patterns.pattern_35'): 'LHX::LHX_3',
#  ('trevino_2021.c1', 'pos_patterns.pattern_37'): 'ZNF143_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_4'): 'LHX_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_5'): 'NFY',
#  ('trevino_2021.c1', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_7'): 'NDF-ATOH_2',
#  ('trevino_2021.c1', 'pos_patterns.pattern_8'): 'POU_1',
#  ('trevino_2021.c1', 'pos_patterns.pattern_9'): 'SP-KLF_1',
#  ('trevino_2021.c1', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c1', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c10', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_1'): 'NFI_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_10'): 'ETS_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_11'): 'POU_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_12'): 'POU_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_14'): 'ATF_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_15'): 'RFX_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_16'): 'SOX::SOX_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_17'): 'BHLH_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_18'): 'ATF_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_19'): 'POU2F_2',
#  ('trevino_2021.c10', 'pos_patterns.pattern_2'): 'SOX::SOX_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_21'): 'ETS::ATF_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_22'): 'ZBTB33',
#  ('trevino_2021.c10', 'pos_patterns.pattern_23'): 'ARNT-USF',
#  ('trevino_2021.c10', 'pos_patterns.pattern_24'): 'YY1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_3'): 'CTCF_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_4'): 'RFX_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_5'): 'AP1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c10', 'pos_patterns.pattern_7'): 'LHX_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_8'): 'SP-KLF_1',
#  ('trevino_2021.c10', 'pos_patterns.pattern_9'): 'NRF1',
#  ('trevino_2021.c10', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c10', 'neg_patterns.pattern_2'): 'ZEB-SNAI::ZEB-SNAI',
#  ('trevino_2021.c11', 'pos_patterns.pattern_0'): 'LHX_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_10'): 'ATF_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_11'): 'ATF_2',
#  ('trevino_2021.c11', 'pos_patterns.pattern_12'): 'POU_2',
#  ('trevino_2021.c11', 'pos_patterns.pattern_13'): 'NRF1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_14'): 'ETS_2',
#  ('trevino_2021.c11', 'pos_patterns.pattern_16'): 'SOX::SOX_2',
#  ('trevino_2021.c11', 'pos_patterns.pattern_17'): 'ZNF143_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_18'): 'POU2F_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_19'): 'POU_3',
#  ('trevino_2021.c11', 'pos_patterns.pattern_2'): 'NFI_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_21'): 'PAX',
#  ('trevino_2021.c11', 'pos_patterns.pattern_22'): 'AP1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_23'): 'YY1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_24'): 'ZBTB33',
#  ('trevino_2021.c11', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_28'): 'ETS::ETS_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_29'): 'BHLH::NFI_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_3'): 'NFI-half_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_31'): 'LHX::NFI',
#  ('trevino_2021.c11', 'pos_patterns.pattern_32'): 'ZNF143_2',
#  ('trevino_2021.c11', 'pos_patterns.pattern_4'): 'SOX::SOX_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_5'): 'RFX_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_6'): 'SP-KLF_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_7'): 'POU_1',
#  ('trevino_2021.c11', 'pos_patterns.pattern_8'): 'NFY',
#  ('trevino_2021.c11', 'pos_patterns.pattern_9'): 'RFX_2',
#  ('trevino_2021.c11', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c11', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c11', 'neg_patterns.pattern_6'): 'NFY-repressive',
#  ('trevino_2021.c8', 'pos_patterns.pattern_0'): 'LHX_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_1'): 'NFI_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_10'): 'SP-KLF_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_11'): 'TBR1_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_12'): 'NRF1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_13'): 'ATF_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_14'): 'ETS_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_15'): 'POU2F_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_16'): 'ZNF143_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_17'): 'POU_3',
#  ('trevino_2021.c8', 'pos_patterns.pattern_18'): 'RFX_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_19'): 'SP-KLF_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_20'): 'POU3F_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_21'): 'SMAD',
#  ('trevino_2021.c8', 'pos_patterns.pattern_22'): 'YY1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_23'): 'POU_4',
#  ('trevino_2021.c8', 'pos_patterns.pattern_24'): 'TFAP2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_25'): 'BHLH_6',
#  ('trevino_2021.c8', 'pos_patterns.pattern_26'): 'HESX1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_27'): 'SOX::POU_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_28'): 'ARNT-USF',
#  ('trevino_2021.c8', 'pos_patterns.pattern_29'): 'BHLH::NFI_4',
#  ('trevino_2021.c8', 'pos_patterns.pattern_3'): 'CTCF_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_30'): 'ZBTB33',
#  ('trevino_2021.c8', 'pos_patterns.pattern_33'): 'AP1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_34'): 'LHX::LHX_3',
#  ('trevino_2021.c8', 'pos_patterns.pattern_37'): 'LHX::NFI',
#  ('trevino_2021.c8', 'pos_patterns.pattern_38'): 'ETS::ETS_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_4'): 'NDF-ATOH_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_41'): 'ETS::ATF_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_43'): 'ZNF143_2',
#  ('trevino_2021.c8', 'pos_patterns.pattern_49'): 'ETS::SP-KLF',
#  ('trevino_2021.c8', 'pos_patterns.pattern_5'): 'BHLH_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_6'): 'POU_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_8'): 'SOX::SOX_1',
#  ('trevino_2021.c8', 'pos_patterns.pattern_9'): 'NFY',
#  ('trevino_2021.c8', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c8', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c14', 'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_10'): 'SP-KLF_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_11'): 'NRF1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_12'): 'ATF_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_13'): 'ETS_2',
#  ('trevino_2021.c14', 'pos_patterns.pattern_14'): 'ZNF143_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_15'): 'POU_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_16'): 'POU6F_2',
#  ('trevino_2021.c14', 'pos_patterns.pattern_17'): 'RFX_2',
#  ('trevino_2021.c14', 'pos_patterns.pattern_18'): 'ZBTB33',
#  ('trevino_2021.c14', 'pos_patterns.pattern_19'): 'MEF2::NDF-ATOH',
#  ('trevino_2021.c14', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_20'): 'YY1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_21'): 'NRF1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_22'): 'SP-KLF_2',
#  ('trevino_2021.c14', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_27'): 'RFX_3',
#  ('trevino_2021.c14', 'pos_patterns.pattern_29'): 'ETS::ATF_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_3'): 'NDF-ATOH_2',
#  ('trevino_2021.c14', 'pos_patterns.pattern_4'): 'LHX_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_5'): 'NFI_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('trevino_2021.c14', 'pos_patterns.pattern_7'): 'NFY',
#  ('trevino_2021.c14', 'pos_patterns.pattern_9'): 'MEF2_1',
#  ('trevino_2021.c14', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c14', 'neg_patterns.pattern_2'): 'BCL11',
#  ('trevino_2021.c14', 'neg_patterns.pattern_5'): 'BCL11',
#  ('trevino_2021.c12', 'pos_patterns.pattern_0'): 'LHX_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_1'): 'NFI_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_10'): 'ETS_2',
#  ('trevino_2021.c12', 'pos_patterns.pattern_11'): 'ATF_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_12'): 'SP-KLF_2',
#  ('trevino_2021.c12', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_14'): 'YY1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_16'): 'ARNT-USF',
#  ('trevino_2021.c12', 'pos_patterns.pattern_17'): 'NRF1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_19'): 'ETS::ATF_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_20'): 'RFX_2',
#  ('trevino_2021.c12', 'pos_patterns.pattern_21'): 'ZBTB33',
#  ('trevino_2021.c12', 'pos_patterns.pattern_22'): 'POU2F_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_23'): 'ETS::ETS_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_25'): 'ZNF143_2',
#  ('trevino_2021.c12', 'pos_patterns.pattern_27'): 'ETS::SP-KLF',
#  ('trevino_2021.c12', 'pos_patterns.pattern_3'): 'BHLH_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_4'): 'SP-KLF_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_5'): 'NFY',
#  ('trevino_2021.c12', 'pos_patterns.pattern_6'): 'POU_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_7'): 'NRF1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_8'): 'RFX_1',
#  ('trevino_2021.c12', 'pos_patterns.pattern_9'): 'SOX::SOX_1',
#  ('trevino_2021.c12', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c12', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c13', 'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_1'): 'NFI-half_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_10'): 'SP-KLF_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_11'): 'POU_3',
#  ('trevino_2021.c13', 'pos_patterns.pattern_12'): 'ATF_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_14'): 'ETS_2',
#  ('trevino_2021.c13', 'pos_patterns.pattern_15'): 'BHLH::NFI_6',
#  ('trevino_2021.c13', 'pos_patterns.pattern_16'): 'NFI::NDF-ATOH',
#  ('trevino_2021.c13', 'pos_patterns.pattern_17'): 'HESX1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_18'): 'YY1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_19'): 'BHLH::NFI_4',
#  ('trevino_2021.c13', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_20'): 'POU3F_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_21'): 'POU4F_3',
#  ('trevino_2021.c13', 'pos_patterns.pattern_22'): 'SP-KLF_2',
#  ('trevino_2021.c13', 'pos_patterns.pattern_23'): 'RFX_2',
#  ('trevino_2021.c13', 'pos_patterns.pattern_24'): 'NFI_11',
#  ('trevino_2021.c13', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_27'): 'NRF1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_28'): 'ZBTB33',
#  ('trevino_2021.c13', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_31'): 'ETS::ETS_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_34'): 'ZNF143_2',
#  ('trevino_2021.c13', 'pos_patterns.pattern_37'): 'ETS::SP-KLF',
#  ('trevino_2021.c13', 'pos_patterns.pattern_4'): 'LHX_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_5'): 'POU_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c13', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_8'): 'NRF1',
#  ('trevino_2021.c13', 'pos_patterns.pattern_9'): 'POU2F_1',
#  ('trevino_2021.c13', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c13', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c21', 'pos_patterns.pattern_0'): 'ETS_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_10'): 'SOX',
#  ('trevino_2021.c21', 'pos_patterns.pattern_11'): 'ZNF143_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_12'): 'AP1::NFAT',
#  ('trevino_2021.c21', 'pos_patterns.pattern_13'): 'ETS::ETS_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_14'): 'TCF7L-LEF_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_15'): 'ETS::ATF_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_16'): 'FOX_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_17'): 'ATF_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_19'): 'ZBTB33',
#  ('trevino_2021.c21', 'pos_patterns.pattern_2'): 'AP1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_26'): 'SP-KLF_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_27'): 'RFX_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_3'): 'NFY',
#  ('trevino_2021.c21', 'pos_patterns.pattern_4'): 'SP-KLF_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_40'): 'AP1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_5'): 'ATF_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_6'): 'FOX_1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_7'): 'NRF1',
#  ('trevino_2021.c21', 'pos_patterns.pattern_8'): 'ETV_2',
#  ('trevino_2021.c21', 'pos_patterns.pattern_9'): 'NFI_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_11'): 'ETS_2',
#  ('trevino_2021.c18', 'pos_patterns.pattern_12'): 'ZNF143_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_14'): 'POU2F_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_15'): 'RFX_2',
#  ('trevino_2021.c18', 'pos_patterns.pattern_16'): 'SP-KLF_2',
#  ('trevino_2021.c18', 'pos_patterns.pattern_17'): 'YY1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_18'): 'POU_3',
#  ('trevino_2021.c18', 'pos_patterns.pattern_19'): 'ZBTB33',
#  ('trevino_2021.c18', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_20'): 'NRF1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_21'): 'ETS::ATF_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_23'): 'ATF_2',
#  ('trevino_2021.c18', 'pos_patterns.pattern_26'): 'ETS::SP-KLF',
#  ('trevino_2021.c18', 'pos_patterns.pattern_28'): 'ZNF143_2',
#  ('trevino_2021.c18', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_4'): 'LHX_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_5'): 'NFY',
#  ('trevino_2021.c18', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_7'): 'SP-KLF_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_8'): 'POU_1',
#  ('trevino_2021.c18', 'pos_patterns.pattern_9'): 'ATF_1',
#  ('trevino_2021.c18', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c18', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c17', 'pos_patterns.pattern_0'): 'ETS_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_11'): 'FOX_2',
#  ('trevino_2021.c17', 'pos_patterns.pattern_12'): 'BHLH_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_14'): 'RFX_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_15'): 'ATF_2',
#  ('trevino_2021.c17', 'pos_patterns.pattern_17'): 'ZBTB33',
#  ('trevino_2021.c17', 'pos_patterns.pattern_2'): 'AP1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_21'): 'NFI_7',
#  ('trevino_2021.c17', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_4'): 'NFY',
#  ('trevino_2021.c17', 'pos_patterns.pattern_5'): 'ATF_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_6'): 'NFI_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_7'): 'MEF2_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_8'): 'FOX_1',
#  ('trevino_2021.c17', 'pos_patterns.pattern_9'): 'EBF',
#  ('trevino_2021.c17', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c17', 'neg_patterns.pattern_5'): 'ZEB-SNAI::ZEB-SNAI',
#  ('trevino_2021.c5', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_1'): 'NDF-ATOH_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_11'): 'ETS_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_12'): 'ATF_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_14'): 'TBR1_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_15'): 'ZBTB33',
#  ('trevino_2021.c5', 'pos_patterns.pattern_16'): 'RFX_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_17'): 'NRF1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_19'): 'NDF-ATOH_3',
#  ('trevino_2021.c5', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_21'): 'YY1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_23'): 'ARNT-USF',
#  ('trevino_2021.c5', 'pos_patterns.pattern_24'): 'TBR1_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_26'): 'SP-KLF_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_28'): 'ATF_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_3'): 'MEF2_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_32'): 'NFI_7',
#  ('trevino_2021.c5', 'pos_patterns.pattern_4'): 'NFI_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_5'): 'NDF-ATOH_2',
#  ('trevino_2021.c5', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('trevino_2021.c5', 'pos_patterns.pattern_7'): 'NFY',
#  ('trevino_2021.c5', 'pos_patterns.pattern_8'): 'SP-KLF_1',
#  ('trevino_2021.c5', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c5', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c5', 'neg_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c5', 'neg_patterns.pattern_4'): 'BCL11',
#  ('trevino_2021.c3', 'pos_patterns.pattern_0'): 'NFI_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_1'): 'LHX_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_11'): 'LHX::LHX_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_12'): 'POU_2',
#  ('trevino_2021.c3', 'pos_patterns.pattern_13'): 'ETS_2',
#  ('trevino_2021.c3', 'pos_patterns.pattern_14'): 'ZNF143_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_15'): 'SP-KLF_2',
#  ('trevino_2021.c3', 'pos_patterns.pattern_16'): 'ATF_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_17'): 'POU2F_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_18'): 'POU_3',
#  ('trevino_2021.c3', 'pos_patterns.pattern_19'): 'YY1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_20'): 'NRF1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_21'): 'ARNT-USF',
#  ('trevino_2021.c3', 'pos_patterns.pattern_22'): 'RFX_2',
#  ('trevino_2021.c3', 'pos_patterns.pattern_23'): 'ETS::ATF_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_25'): 'ZBTB33',
#  ('trevino_2021.c3', 'pos_patterns.pattern_27'): 'ETS::ETS_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_28'): 'ZNF143_2',
#  ('trevino_2021.c3', 'pos_patterns.pattern_3'): 'CTCF_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_4'): 'BHLH_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_5'): 'SOX::SOX_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_6'): 'POU_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_7'): 'NFY',
#  ('trevino_2021.c3', 'pos_patterns.pattern_8'): 'SP-KLF_1',
#  ('trevino_2021.c3', 'pos_patterns.pattern_9'): 'RFX_1',
#  ('trevino_2021.c3', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c3', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c3', 'neg_patterns.pattern_5'): 'NFY-repressive',
#  ('trevino_2021.c0', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_1'): 'NDF-ATOH_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_10'): 'POU2F_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_11'): 'POU_3',
#  ('trevino_2021.c0', 'pos_patterns.pattern_12'): 'NRF1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_13'): 'ATF_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_14'): 'NFI_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_15'): 'ZNF143_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_16'): 'POU::POU',
#  ('trevino_2021.c0', 'pos_patterns.pattern_17'): 'ETS_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_18'): 'POU3F_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_19'): 'SP-KLF_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_20'): 'POU_9',
#  ('trevino_2021.c0', 'pos_patterns.pattern_21'): 'RFX_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_22'): 'YY1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_23'): 'ARNT-USF',
#  ('trevino_2021.c0', 'pos_patterns.pattern_24'): 'NRF1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_26'): 'ZBTB33',
#  ('trevino_2021.c0', 'pos_patterns.pattern_28'): 'ATF_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_34'): 'ETS::ETS_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_35'): 'ZNF143_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_37'): 'ETS::SP-KLF',
#  ('trevino_2021.c0', 'pos_patterns.pattern_4'): 'NDF-ATOH_2',
#  ('trevino_2021.c0', 'pos_patterns.pattern_5'): 'LHX_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c0', 'pos_patterns.pattern_7'): 'POU_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_8'): 'RFX_1',
#  ('trevino_2021.c0', 'pos_patterns.pattern_9'): 'SP-KLF_1',
#  ('trevino_2021.c0', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c0', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c7', 'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_1'): 'NFI-half_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_10'): 'POU2F_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_11'): 'LHX_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_12'): 'POU_3',
#  ('trevino_2021.c7', 'pos_patterns.pattern_13'): 'ETS_2',
#  ('trevino_2021.c7', 'pos_patterns.pattern_14'): 'ATF_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_15'): 'ZNF143_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_16'): 'SP-KLF_2',
#  ('trevino_2021.c7', 'pos_patterns.pattern_17'): 'YY1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_18'): 'BHLH::NFI_3',
#  ('trevino_2021.c7', 'pos_patterns.pattern_19'): 'POU::POU',
#  ('trevino_2021.c7', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_20'): 'POU3F_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_21'): 'POU_8',
#  ('trevino_2021.c7', 'pos_patterns.pattern_22'): 'ZBTB33',
#  ('trevino_2021.c7', 'pos_patterns.pattern_23'): 'RFX_2',
#  ('trevino_2021.c7', 'pos_patterns.pattern_24'): 'ARNT-USF',
#  ('trevino_2021.c7', 'pos_patterns.pattern_25'): 'ETS::ATF_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_26'): 'POU_6',
#  ('trevino_2021.c7', 'pos_patterns.pattern_27'): 'POU4F_3',
#  ('trevino_2021.c7', 'pos_patterns.pattern_29'): 'ZNF143_2',
#  ('trevino_2021.c7', 'pos_patterns.pattern_3'): 'NDF-ATOH_2',
#  ('trevino_2021.c7', 'pos_patterns.pattern_4'): 'NFI_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_5'): 'POU_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c7', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_8'): 'NRF1',
#  ('trevino_2021.c7', 'pos_patterns.pattern_9'): 'SP-KLF_1',
#  ('trevino_2021.c7', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c7', 'neg_patterns.pattern_1'): 'ZEB-SNAI',
#  ('trevino_2021.c15', 'pos_patterns.pattern_0'): 'SOX::SOX_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_10'): 'SP-KLF_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_11'): 'NRF1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_12'): 'ZNF143_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_13'): 'ETS_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_14'): 'ATF_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_15'): 'POU_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_16'): 'ETS::ATF_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_17'): 'ZBTB33',
#  ('trevino_2021.c15', 'pos_patterns.pattern_18'): 'NRF1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_19'): 'RFX_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_2'): 'SOX::SOX_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_21'): 'POU2F_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_22'): 'YY1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_23'): 'SP-KLF_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_24'): 'ETS::SP-KLF',
#  ('trevino_2021.c15', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_4'): 'SOX::SOX_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_5'): 'BHLH_1',
#  ('trevino_2021.c15', 'pos_patterns.pattern_6'): 'SOX::SOX_3',
#  ('trevino_2021.c15', 'pos_patterns.pattern_7'): 'NFY',
#  ('trevino_2021.c15', 'pos_patterns.pattern_8'): 'SOX::SOX_2',
#  ('trevino_2021.c15', 'pos_patterns.pattern_9'): 'RFX_1',
#  ('trevino_2021.c15', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c6', 'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_11'): 'POU_3',
#  ('trevino_2021.c6', 'pos_patterns.pattern_12'): 'POU2F_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_13'): 'ETS_2',
#  ('trevino_2021.c6', 'pos_patterns.pattern_14'): 'ATF_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_15'): 'ZNF143_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_16'): 'BHLH::NFI_3',
#  ('trevino_2021.c6', 'pos_patterns.pattern_17'): 'POU::POU',
#  ('trevino_2021.c6', 'pos_patterns.pattern_18'): 'BHLH::NFI_5',
#  ('trevino_2021.c6', 'pos_patterns.pattern_19'): 'SP-KLF_2',
#  ('trevino_2021.c6', 'pos_patterns.pattern_2'): 'NFI-half_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_20'): 'YY1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_21'): 'FOX::MEIS',
#  ('trevino_2021.c6', 'pos_patterns.pattern_22'): 'NRF1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_23'): 'RFX_2',
#  ('trevino_2021.c6', 'pos_patterns.pattern_24'): 'POU_6',
#  ('trevino_2021.c6', 'pos_patterns.pattern_26'): 'ETS::ATF_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_27'): 'HESX1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_28'): 'ZBTB33',
#  ('trevino_2021.c6', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_30'): 'ZNF143_2',
#  ('trevino_2021.c6', 'pos_patterns.pattern_4'): 'NDF-ATOH_2',
#  ('trevino_2021.c6', 'pos_patterns.pattern_5'): 'LHX_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_6'): 'NFY',
#  ('trevino_2021.c6', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_8'): 'POU_1',
#  ('trevino_2021.c6', 'pos_patterns.pattern_9'): 'SP-KLF_1',
#  ('trevino_2021.c6', 'neg_patterns.pattern_0'): 'BCL11',
#  ('trevino_2021.c6', 'neg_patterns.pattern_1'): 'BCL11',
#  ('trevino_2021.c6', 'neg_patterns.pattern_2'): 'NFY-repressive',
#  ('trevino_2021.c2', 'pos_patterns.pattern_0'): 'NFI-half_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_1'): 'NDF-ATOH_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_10'): 'NRF1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_11'): 'NFI_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_12'): 'POU_3',
#  ('trevino_2021.c2', 'pos_patterns.pattern_13'): 'POU2F_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_14'): 'ATF_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_15'): 'ZNF143_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_16'): 'NFI_3',
#  ('trevino_2021.c2', 'pos_patterns.pattern_17'): 'SOX::POU_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_18'): 'ETS_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_19'): 'POU3F_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_20'): 'NFI_4',
#  ('trevino_2021.c2', 'pos_patterns.pattern_21'): 'SOX::POU_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_22'): 'RFX_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_23'): 'YY1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_24'): 'ARNT-USF',
#  ('trevino_2021.c2', 'pos_patterns.pattern_25'): 'ZBTB33',
#  ('trevino_2021.c2', 'pos_patterns.pattern_26'): 'SP-KLF_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_27'): 'ETS::ATF_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_29'): 'POU_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_3'): 'MEIS',
#  ('trevino_2021.c2', 'pos_patterns.pattern_35'): 'ETS::ETS_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_38'): 'ETS::SP-KLF',
#  ('trevino_2021.c2', 'pos_patterns.pattern_4'): 'NFI_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_5'): 'NFY',
#  ('trevino_2021.c2', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_7'): 'NDF-ATOH_2',
#  ('trevino_2021.c2', 'pos_patterns.pattern_8'): 'POU_1',
#  ('trevino_2021.c2', 'pos_patterns.pattern_9'): 'SP-KLF_1',
#  ('trevino_2021.c2', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('trevino_2021.c2', 'neg_patterns.pattern_1'): 'BCL11',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_0'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_1'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_10'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_11'): 'ETS::ATF_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_12'): 'RFX_3',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_13'): 'YY1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_15'): 'HSF1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_2'): 'NFY',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_3'): 'RFX_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_4'): 'ATF_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_5'): 'NRF1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_6'): 'ETS_2',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_7'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_8'): 'RFX_2',
#  ('domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells',
#   'pos_patterns.pattern_9'): 'NRF1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_0'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_1'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_12'): 'RFX_2',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_13'): 'E2F_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_15'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_16'): 'E2F_3',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_19'): 'YY1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_2'): 'NFY',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_21'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_3'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_4'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_5'): 'RFX_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_6'): 'NRF1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_7'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_8'): 'TCF7L-LEF_1',
#  ('domcke_2020.fetal_brain.Limbic_system_neurons',
#   'pos_patterns.pattern_9'): 'NRF1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_0'): 'NFI_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Astrocytes',
#   'pos_patterns.pattern_10'): 'SOX::SOX_7',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_11'): 'POU_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_12'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_13'): 'RFX_2',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_14'): 'POU_2',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_15'): 'ATF_2',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_16'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_18'): 'POU2F_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_19'): 'YY1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_2'): 'LHX_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_20'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_4'): 'NFY',
#  ('domcke_2020.fetal_brain.Astrocytes',
#   'pos_patterns.pattern_5'): 'NFI-half_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_6'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_8'): 'NRF1',
#  ('domcke_2020.fetal_brain.Astrocytes', 'pos_patterns.pattern_9'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Astrocytes', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_0'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_1'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_10'): 'POU_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_11'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_12'): 'YY1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_13'): 'NRF1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_14'): 'RFX_2',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_15'): 'POU_7',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_16'): 'LHX::LHX_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_17'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_18'): 'ETS::ATF_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_2'): 'NFY',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_20'): 'POU4F_2',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_21'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_22'): 'LHX::LHX_2',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_23'): 'POU2F_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_3'): 'NFI_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_30'): 'HSF1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_4'): 'LHX_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_5'): 'BHLH_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_6'): 'RFX_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_7'): 'NRF1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_8'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Inhibitory_neurons',
#   'pos_patterns.pattern_9'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_1'): 'NFI-half_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_10'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_11'): 'POU_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_12'): 'MEF2_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_13'): 'YY1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_14'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_16'): 'POU2F_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_17'): 'ARNT-USF',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_18'): 'RFX_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_19'): 'NRF1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_2'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_20'): 'POU_3',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_21'): 'MEF2_3',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_22'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_23'): 'ETS::ATF_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_24'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_27'): 'HSF1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_29'): 'POU::POU',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_3'): 'NFI_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_30'): 'ATF_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_4'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_5'): 'NDF-ATOH_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_6'): 'NFY',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_7'): 'RFX_1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_8'): 'NRF1',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'pos_patterns.pattern_9'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('domcke_2020.fetal_brain.Excitatory_neurons',
#   'neg_patterns.pattern_1'): 'BCL11',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_0'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_1'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_10'): 'ETS::ETS_1',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_11'): 'ETS_1',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_13'): 'SP-KLF_3',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_15'): 'ETS_4',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
#   'pos_patterns.pattern_17'): 'ETS_3',
#  ('domcke_2020.fetal_brain.Vascular_endothelial_cells',
# ...
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_17'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_2'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_22'): 'ETS_3',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_3'): 'NFI-half_1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_4'): 'NFY',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_5'): 'RFX_1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_6'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_7'): 'SOX::SOX_1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_8'): 'NRF1',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'pos_patterns.pattern_9'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes',
#   'neg_patterns.pattern_5'): 'ZEB-SNAI::ZEB-SNAI',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_0'): 'NDF-ATOH_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_1'): 'CTCF_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_10'): 'ETS_2',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_11'): 'POU_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_12'): 'ZNF143_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_13'): 'SMAD',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_14'): 'POU_3',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_15'): 'POU2F_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_16'): 'YY1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_17'): 'ZBTB33',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_18'): 'ETS::ATF_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_19'): 'RFX_2',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_2'): 'LHX_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_20'): 'ATF_2',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_21'): 'LHX::LHX_2',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_23'): 'LHX::LHX_3',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_26'): 'ZNF143_2',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_28'): 'LHX::NFI',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_3'): 'NFI-half_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_4'): 'NFI_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_5'): 'SP-KLF_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_6'): 'NFY',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_7'): 'NRF1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_8'): 'ATF_1',
#  ('domcke_2020.fetal_brain.Cerebrum_Unknown_3',
#   'pos_patterns.pattern_9'): 'RFX_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_0'): 'SOX::SOX_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_1'): 'SOX::SOX_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_10'): 'NRF1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_11'): 'ETS_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_13'): 'RFX_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_14'): 'POU_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_15'): 'ZNF143_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_16'): 'ATF_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_17'): 'SP-KLF_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_18'): 'NR3C',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_19'): 'YY1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_20'): 'ETS::ATF_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_22'): 'NFI_7',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_23'): 'ZBTB33',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_25'): 'ZNF143_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_26'): 'RFX_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_3'): 'NFI_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_4'): 'BHLH_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_5'): 'NFI-half_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_6'): 'SP-KLF_1',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_7'): 'SOX::SOX_2',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_8'): 'NFY',
#  ('corces_2020.Cluster9', 'pos_patterns.pattern_9'): 'SOX::SOX_2',
#  ('corces_2020.Cluster9', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('corces_2020.Cluster9', 'neg_patterns.pattern_1'): 'NFY-repressive',
#  ('corces_2020.Cluster9', 'neg_patterns.pattern_6'): 'BCL11',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_0'): 'EGR_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_1'): 'MEF2_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_10'): 'TEF',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_11'): 'NFY',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_12'): 'SP-KLF_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_13'): 'NRF1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_14'): 'BHLH_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_15'): 'BHLH_3',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_16'): 'RFX_2',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_17'): 'ETS_2',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_18'): 'TBR1_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_19'): 'ZNF143_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_2'): 'CTCF_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_20'): 'ATF_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_21'): 'BHLH_4',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_22'): 'NHLH',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_23'): 'TBR1_2',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_24'): 'ZBTB33',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_25'): 'YY1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_27'): 'ZNF143_2',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_28'): 'BHLH::NFI_4',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_3'): 'AP1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_31'): 'ATF_2',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_33'): 'ETS::ATF_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_38'): 'ETS_3',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_4'): 'NDF-ATOH_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_5'): 'NFI-half_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_6'): 'RFX_1',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_7'): 'NR3C',
#  ('corces_2020.Cluster4', 'pos_patterns.pattern_8'): 'NFI_1',
#  ('corces_2020.Cluster4', 'neg_patterns.pattern_0'): 'BCL11',
#  ('corces_2020.Cluster4', 'neg_patterns.pattern_3'): 'NFY-repressive',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_0'): 'CTCF_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_1'): 'SP-KLF_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_10'): 'SOX::SOX_8',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_11'): 'SOX::SOX_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_12'): 'SOX::SOX_9',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_14'): 'SOX::SOX_10',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_15'): 'ATF_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_16'): 'RFX_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_17'): 'BHLH_5',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_18'): 'ETS::ATF_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_2'): 'NFY',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_3'): 'SOX::SOX_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_4'): 'NFI_1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_6'): 'NRF1',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_7'): 'ETS_2',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_8'): 'BHLH_2',
#  ('corces_2020.Cluster10', 'pos_patterns.pattern_9'): 'SOX::SOX_6',
#  ('corces_2020.Cluster10', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('corces_2020.Cluster10', 'neg_patterns.pattern_14'): 'ZEB-SNAI::ZEB-SNAI',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_0'): 'SOX::SOX_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_10'): 'NFI-half_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_11'): 'AP1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_12'): 'ARNT-USF',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_14'): 'YY1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_15'): 'ATF_2',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_16'): 'SOX::SOX_2',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_17'): 'SOX::SOX_11',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_18'): 'SOX::SOX_4',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_19'): 'SOX::SOX_5',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_2'): 'SOX::SOX_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_20'): 'RFX_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_21'): 'ETS::ATF_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_22'): 'ZNF143_2',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_23'): 'ZBTB33',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_24'): 'SOX::SOX_2',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_25'): 'SOX::SOX_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_28'): 'ETS::SP-KLF',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_4'): 'BHLH_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_5'): 'NFI_1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_6'): 'NFY',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_7'): 'NRF1',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_8'): 'ETS_2',
#  ('corces_2020.Cluster20', 'pos_patterns.pattern_9'): 'ATF_1',
#  ('corces_2020.Cluster20', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('corces_2020.Cluster20', 'neg_patterns.pattern_1'): 'NFY-repressive',
#  ('corces_2020.Cluster20', 'neg_patterns.pattern_6'): 'ZBTB7',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_0'): 'CTCF_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_1'): 'SOX::SOX_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_10'): 'NFI-half_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_11'): 'AP1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_12'): 'ATF_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_13'): 'ARNT-USF',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_14'): 'ZNF143_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_15'): 'ATF_2',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_16'): 'YY1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_17'): 'SOX::SOX_2',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_18'): 'SOX::SOX_4',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_19'): 'SOX::SOX_5',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_2'): 'SOX::SOX_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_20'): 'RFX_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_21'): 'ETS::ATF_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_22'): 'ZBTB33',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_23'): 'ZNF143_2',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_24'): 'SOX::SOX_2',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_27'): 'ETS::SP-KLF',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_34'): 'RFX_2',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_4'): 'SOX::SOX_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_5'): 'BHLH_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_6'): 'NFI_1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_7'): 'NFY',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_8'): 'NRF1',
#  ('corces_2020.Cluster22', 'pos_patterns.pattern_9'): 'ETS_2',
#  ('corces_2020.Cluster22', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('corces_2020.Cluster22', 'neg_patterns.pattern_1'): 'NFY-repressive',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_0'): 'CTCF_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_1'): 'SP-KLF_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_10'): 'ZNF143_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_13'): 'ZBTB33',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_15'): 'ETS::ATF_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_19'): 'SP-KLF_2',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_2'): 'SOX::SOX_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_21'): 'ETS::ETS_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_22'): 'AP1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_26'): 'ETS_4',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_27'): 'ETS_3',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_3'): 'NFY',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_30'): 'SP-KLF_3',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_4'): 'NRF1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_5'): 'ETS_2',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_6'): 'ATF_1',
#  ('corces_2020.Cluster8', 'pos_patterns.pattern_9'): 'RFX_1',
#  ('corces_2020.Cluster8', 'neg_patterns.pattern_0'): 'ZEB-SNAI',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_0'): 'EGR_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_1'): 'CTCF_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_10'): 'TEF',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_11'): 'ATF_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_12'): 'SOX::SOX_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_13'): 'ZNF143_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_14'): 'BHLH_2',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_15'): 'NFI_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_16'): 'RFX_2',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_17'): 'YY1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_18'): 'SOX::SOX_3',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_19'): 'ARNT-USF',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_2'): 'AP1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_21'): 'ZBTB33',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_22'): 'NFI-half_3',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_23'): 'SOX::SOX_14',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_24'): 'ETS::ATF_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_25'): 'HLF',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_26'): 'ZNF143_2',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_28'): 'ATF_2',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_3'): 'SP-KLF_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_31'): 'ETS::SP-KLF',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_4'): 'NRF1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_5'): 'NFY',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_6'): 'MEF2_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_7'): 'RFX_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_8'): 'SOX::SOX_1',
#  ('corces_2020.Cluster7', 'pos_patterns.pattern_9'): 'ETS_2',
#  ('corces_2020.Cluster7', 'neg_patterns.pattern_0'): 'BCL11',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_0'): 'CTCF_1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_1'): 'SOX::SOX_1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_10'): 'ATF_1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_11'): 'ZNF143_1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_12'): 'NFI-half_1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_13'): 'ARNT-USF',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_14'): 'SOX::SOX_2',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_15'): 'NRF1',
#  ('corces_2020.Cluster19', 'pos_patterns.pattern_16'): 'AP1',
#  ...}

# %%
merged_pattern_to_cluster = {row['clustered_pattern']: row['manual_annotation'] for _, row in mc_avg_manual_annotations_filtered.iterrows()}

merged_pattern_to_cluster
# Out:
# {'pos_patterns.pattern_0': 'NRF1',
#  'pos_patterns.pattern_1': 'SP-KLF_1',
#  'pos_patterns.pattern_2': 'ATF_1',
#  'pos_patterns.pattern_3': 'ZNF143_1',
#  'pos_patterns.pattern_4': 'NFY',
#  'pos_patterns.pattern_5': 'CTCF_1',
#  'pos_patterns.pattern_6': 'ZBTB33',
#  'pos_patterns.pattern_7': 'ETS_2',
#  'pos_patterns.pattern_8': 'RFX_1',
#  'pos_patterns.pattern_9': 'ETS::ATF_1',
#  'pos_patterns.pattern_10': 'NFI_1',
#  'neg_patterns.pattern_0': 'ZEB-SNAI',
#  'pos_patterns.pattern_11': 'YY1',
#  'pos_patterns.pattern_12': 'RFX_2',
#  'pos_patterns.pattern_13': 'ZNF143_2',
#  'pos_patterns.pattern_14': 'SOX::SOX_1',
#  'pos_patterns.pattern_15': 'NFI-half_1',
#  'neg_patterns.pattern_1': 'BCL11',
#  'pos_patterns.pattern_17': 'ARNT-USF',
#  'pos_patterns.pattern_18': 'AP1',
#  'pos_patterns.pattern_19': 'ATF_2',
#  'pos_patterns.pattern_20': 'POU_1',
#  'pos_patterns.pattern_21': 'LHX_1',
#  'pos_patterns.pattern_22': 'BHLH_1',
#  'pos_patterns.pattern_23': 'SP-KLF_2',
#  'pos_patterns.pattern_24': 'POU2F_1',
#  'pos_patterns.pattern_25': 'ETS::SP-KLF',
#  'pos_patterns.pattern_26': 'SOX::SOX_2',
#  'pos_patterns.pattern_27': 'NDF-ATOH_1',
#  'pos_patterns.pattern_28': 'ETS::ETS_1',
#  'pos_patterns.pattern_29': 'MEF2_1',
#  'neg_patterns.pattern_2': 'NFY-repressive',
#  'pos_patterns.pattern_30': 'POU_3',
#  'pos_patterns.pattern_32': 'POU_2',
#  'pos_patterns.pattern_33': 'NR3C',
#  'pos_patterns.pattern_34': 'NFI_7',
#  'neg_patterns.pattern_3': 'ZEB-SNAI::ZEB-SNAI',
#  'pos_patterns.pattern_35': 'TEF',
#  'pos_patterns.pattern_36': 'NDF-ATOH_2',
#  'pos_patterns.pattern_37': 'ETS_1',
#  'pos_patterns.pattern_38': 'HLF',
#  'pos_patterns.pattern_42': 'EGR_1',
#  'pos_patterns.pattern_43': 'POU::POU',
#  'pos_patterns.pattern_44': 'HSF1',
#  'pos_patterns.pattern_45': 'LHX::LHX_2',
#  'pos_patterns.pattern_47': 'HESX1',
#  'pos_patterns.pattern_51': 'ETS_3',
#  'pos_patterns.pattern_53': 'SOX::SOX_4',
#  'pos_patterns.pattern_55': 'SOX::SOX_5',
#  'pos_patterns.pattern_56': 'TBR1_1',
#  'pos_patterns.pattern_57': 'POU3F_1',
#  'pos_patterns.pattern_59': 'SP-KLF_3',
#  'pos_patterns.pattern_60': 'LHX::LHX_3',
#  'pos_patterns.pattern_61': 'BHLH::NFI_4',
#  'pos_patterns.pattern_62': 'LHX::NFI',
#  'pos_patterns.pattern_64': 'LHX::LHX_1',
#  'pos_patterns.pattern_66': 'BHLH::NFI_1',
#  'neg_patterns.pattern_11': 'ZBTB7',
#  'pos_patterns.pattern_67': 'SOX::POU_1',
#  'pos_patterns.pattern_73': 'SOX::SOX_3',
#  'pos_patterns.pattern_75': 'RFX_3',
#  'pos_patterns.pattern_77': 'NFI_8',
#  'pos_patterns.pattern_79': 'ROR',
#  'pos_patterns.pattern_80': 'TBR1_2',
#  'pos_patterns.pattern_83': 'IRF_2',
#  'pos_patterns.pattern_84': 'IRF_1',
#  'pos_patterns.pattern_87': 'POU_4',
#  'pos_patterns.pattern_92': 'NFI::NDF-ATOH',
#  'pos_patterns.pattern_93': 'POU4F_3',
#  'pos_patterns.pattern_95': 'FOX_2',
#  'pos_patterns.pattern_99': 'FOX_1',
#  'pos_patterns.pattern_104': 'NFI_2',
#  'pos_patterns.pattern_107': 'BHLH::NFI_3',
#  'pos_patterns.pattern_108': 'POU_6',
#  'pos_patterns.pattern_110': 'POU2F_2',
#  'pos_patterns.pattern_112': 'POU4F_2',
#  'pos_patterns.pattern_117': 'ETS_4',
#  'pos_patterns.pattern_118': 'SMAD',
#  'pos_patterns.pattern_120': 'BHLH_3',
#  'pos_patterns.pattern_121': 'BHLH_2',
#  'pos_patterns.pattern_138': 'NFI_5',
#  'pos_patterns.pattern_151': 'BHLH::NFI_2',
#  'pos_patterns.pattern_153': 'SPI',
#  'pos_patterns.pattern_158': 'MEIS',
#  'pos_patterns.pattern_160': 'IRF_3',
#  'pos_patterns.pattern_161': 'CEBP_1',
#  'pos_patterns.pattern_162': 'LHX::LHX_4',
#  'pos_patterns.pattern_175': 'POU_5',
#  'pos_patterns.pattern_192': 'LHX::LHX_5',
#  'pos_patterns.pattern_207': 'NFI_6',
#  'pos_patterns.pattern_222': 'PAX',
#  'pos_patterns.pattern_234': 'POU3F_2',
#  'pos_patterns.pattern_235': 'TFAP2',
#  'pos_patterns.pattern_236': 'BHLH_6',
#  'pos_patterns.pattern_250': 'POU6F_2',
#  'pos_patterns.pattern_251': 'MEF2::NDF-ATOH',
#  'pos_patterns.pattern_266': 'BHLH::NFI_6',
#  'pos_patterns.pattern_267': 'NFI_11',
#  'pos_patterns.pattern_275': 'SOX',
#  'pos_patterns.pattern_276': 'AP1::NFAT',
#  'pos_patterns.pattern_277': 'ETS::ETS_2',
#  'pos_patterns.pattern_278': 'TCF7L-LEF_2',
#  'pos_patterns.pattern_279': 'ETS::ATF_2',
#  'pos_patterns.pattern_299': 'ETV_2',
#  'pos_patterns.pattern_309': 'EBF',
#  'pos_patterns.pattern_310': 'NDF-ATOH_3',
#  'pos_patterns.pattern_328': 'POU_9',
#  'pos_patterns.pattern_337': 'POU_8',
#  'pos_patterns.pattern_345': 'BHLH::NFI_5',
#  'pos_patterns.pattern_346': 'FOX::MEIS',
#  'pos_patterns.pattern_359': 'NFI_3',
#  'pos_patterns.pattern_360': 'SOX::POU_2',
#  'pos_patterns.pattern_361': 'NFI_4',
#  'pos_patterns.pattern_375': 'E2F_1',
#  'pos_patterns.pattern_376': 'E2F_3',
#  'pos_patterns.pattern_384': 'TCF7L-LEF_1',
#  'pos_patterns.pattern_385': 'SOX::SOX_7',
#  'pos_patterns.pattern_391': 'POU_7',
#  'pos_patterns.pattern_400': 'MEF2_3',
#  'pos_patterns.pattern_428': 'BHLH_4',
#  'pos_patterns.pattern_429': 'NHLH',
#  'pos_patterns.pattern_440': 'SOX::SOX_8',
#  'pos_patterns.pattern_441': 'SOX::SOX_9',
#  'pos_patterns.pattern_442': 'SOX::SOX_10',
#  'pos_patterns.pattern_443': 'BHLH_5',
#  'pos_patterns.pattern_451': 'SOX::SOX_6',
#  'pos_patterns.pattern_452': 'SOX::SOX_11',
#  'pos_patterns.pattern_483': 'NFI-half_3',
#  'pos_patterns.pattern_484': 'SOX::SOX_14',
#  'pos_patterns.pattern_500': 'NFI_9',
#  'pos_patterns.pattern_532': 'SP-KLF_4',
#  'pos_patterns.pattern_566': 'POU6F_1',
#  'pos_patterns.pattern_575': 'CEBP_2',
#  'pos_patterns.pattern_582': 'EGR::NDF-ATOH',
#  'pos_patterns.pattern_583': 'HAND',
#  'pos_patterns.pattern_584': 'EGR_2',
#  'pos_patterns.pattern_604': 'BHLH::BHLH',
#  'pos_patterns.pattern_605': 'MEF2_4',
#  'pos_patterns.pattern_615': 'MEF2_2',
#  'pos_patterns.pattern_616': 'CTCF_2',
#  'pos_patterns.pattern_617': 'BHLH_7',
#  'pos_patterns.pattern_618': 'MEF2_5',
#  'pos_patterns.pattern_643': 'RFX_5',
#  'pos_patterns.pattern_645': 'NFI_10',
#  'pos_patterns.pattern_669': 'SOX::SOX_12',
#  'pos_patterns.pattern_670': 'SOX::SOX_13',
#  'pos_patterns.pattern_671': 'E2F_2',
#  'pos_patterns.pattern_676': 'NFI-half_2',
#  'pos_patterns.pattern_677': 'RFX_4',
#  'pos_patterns.pattern_678': 'DLX',
#  'pos_patterns.pattern_680': 'LHX_2',
#  'pos_patterns.pattern_681': 'POU4F_1',
#  'pos_patterns.pattern_694': 'RUNX',
#  'pos_patterns.pattern_695': 'ETV_1',
#  'pos_patterns.pattern_696': 'MAF'}

# %%
def process_variant_motifs(file_info, original_pattern_to_cluster, merged_pattern_to_cluster):
    """Process original and clustered motif hits for variant alleles and construct a variant-by-motif table."""
    original_file_path, clustered_file_path, sample = file_info

    # Load original motif annotations
    original_df = pd.read_table(original_file_path)
    original_df = original_df[['peak_id', 'chr', 'variant_loc', 'motif_name', 'allele']]

    # Map motifs to clusters using (sample, motif_name) as the key
    original_df['motif_cluster'] = original_df.apply(lambda row: original_pattern_to_cluster.get((sample, row['motif_name'])), axis=1)
    
    # Remove motifs not found in the mapping
    original_df = original_df.dropna(subset=['motif_cluster'])
    original_df.drop(columns=['motif_name'], inplace=True)
    original_df.rename(columns={'motif_cluster': 'motif_name'}, inplace=True)

    # Unique motif clusters detected in the original file
    detected_clusters = set(original_df['motif_name'])

    ## ---- ##

    # Load clustered motif annotations
    clustered_df = pd.read_table(clustered_file_path)
    clustered_df = clustered_df[['peak_id', 'chr', 'variant_loc', 'motif_name', 'allele']]

    # Map motifs to clusters, using (sample, motif_name) as the key
    clustered_df['motif_cluster'] = clustered_df.apply(lambda row: merged_pattern_to_cluster.get(row['motif_name']), axis=1)

    # Remove motifs not found in the mapping
    clustered_df = clustered_df.dropna(subset=['motif_cluster'])
    clustered_df.drop(columns=['motif_name'], inplace=True)
    clustered_df.rename(columns={'motif_cluster': 'motif_name'}, inplace=True)

    # Remove motif clusters that were already found in the original file
    clustered_df = clustered_df[~clustered_df['motif_name'].isin(detected_clusters)]

    # Merge original and filtered clustered motif hits
    merged_df = pd.concat([original_df, clustered_df], ignore_index=True)

    merged_df = merged_df[~merged_df['motif_name'].isin(EXCLUDED_MOTIFS)]

    # Group and combine motif names per allele
    grouped = (
        merged_df.groupby(["chr", "variant_loc", "allele"])["motif_name"]
        .apply(lambda x: ", ".join(x))
        .reset_index()
    )

    # Pivot so each allele is its own column
    collapsed = grouped.pivot(index=["chr", "variant_loc"], columns="allele", values="motif_name").reset_index()

    # Rename columns for clarity
    collapsed = collapsed.rename(
        columns={
            "allele1": "motifs_allele1",
            "allele2": "motifs_allele2"
        }
    )

    # Combine all allele motifs
    collapsed['all_alleles'] = collapsed[['motifs_allele1', 'motifs_allele2']].apply(
        lambda row: ",".join([v for v in row if pd.notna(v)]),
        axis=1
    )

    # Update column names to include sample name
    collapsed.rename(
        columns={
            'chr': 'chr_hg38', 'variant_loc': 'pos_hg38',
            'motifs_allele1': f"{sample}.ref_allele_motifs",
            'motifs_allele2': f"{sample}.alt_allele_motifs",
            'all_alleles': f"{sample}.all_motifs"
        },
        inplace=True
    )

    return collapsed

# %%
file_infos = []

for dataset in os.listdir(data_dir):
    for sample in os.listdir(os.path.join(data_dir, dataset, 'all_data_all_patterns', leiden)):
        print(sample)
        file_infos.append((
            os.path.join(data_dir, dataset, 'original_modisco', sample, fold, score_type, alpha, 'variant_hit_calls.tsv'),  # Original file
            os.path.join(data_dir, dataset, 'all_data_all_patterns', leiden, sample, fold, score_type, alpha, 'variant_hit_calls.tsv'),  # Clustered file
            sample
        ))
# Out:
# trevino_2021.c20
# trevino_2021.c19
# trevino_2021.c9
# trevino_2021.c16
# trevino_2021.c4
# trevino_2021.c1
# trevino_2021.c10
# trevino_2021.c11
# trevino_2021.c8
# trevino_2021.c14
# trevino_2021.c12
# trevino_2021.c13
# trevino_2021.c21
# trevino_2021.c18
# trevino_2021.c17
# trevino_2021.c5
# trevino_2021.c3
# trevino_2021.c0
# trevino_2021.c7
# trevino_2021.c15
# trevino_2021.c6
# trevino_2021.c2
# domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells
# domcke_2020.fetal_brain.Limbic_system_neurons
# domcke_2020.fetal_brain.Astrocytes
# domcke_2020.fetal_brain.Inhibitory_neurons
# domcke_2020.fetal_brain.Excitatory_neurons
# domcke_2020.fetal_brain.Vascular_endothelial_cells
# domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes
# domcke_2020.fetal_brain.Cerebrum_Unknown_3
# corces_2020.Cluster9
# corces_2020.Cluster4
# corces_2020.Cluster10
# corces_2020.Cluster20
# corces_2020.Cluster22
# corces_2020.Cluster8
# corces_2020.Cluster7
# corces_2020.Cluster19
# corces_2020.Cluster15
# corces_2020.Cluster13
# corces_2020.Cluster5
# corces_2020.Cluster18
# corces_2020.Cluster21
# corces_2020.Cluster16
# corces_2020.Cluster14
# corces_2020.Cluster3
# corces_2020.Cluster6
# corces_2020.Cluster12
# corces_2020.Cluster1
# corces_2020.Cluster2
# corces_2020.Cluster23
# corces_2020.Cluster17
# corces_2020.Cluster11
# corces_2020.Cluster24

# %%
file_infos
# Out:
# [('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c20/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c20/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c20'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c19/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c19/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c19'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c9/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c9/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c9'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c16/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c16/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c16'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c4/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c4/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c4'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c1/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c1/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c1'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c10/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c10/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c10'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c11/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c11/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c11'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c8/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c8/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c8'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c14/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c14/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c14'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c12/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c12/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c12'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c13/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c13/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c13'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c21/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c21/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c21'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c18/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c18/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c18'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c17/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c17/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c17'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c5/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c5/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c5'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c3'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c0/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c0/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c0'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c7/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c7/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c7'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c15/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c15/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c15'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c6/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c6/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c6'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/original_modisco/trevino_2021.c2/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/trevino_2021/all_data_all_patterns/leiden_96/trevino_2021.c2/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'trevino_2021.c2'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.SKOR2_NPSR1_positive_cells'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Limbic_system_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Limbic_system_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Limbic_system_neurons'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Astrocytes/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Astrocytes/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Astrocytes'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Inhibitory_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Inhibitory_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Inhibitory_neurons'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Excitatory_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Excitatory_neurons/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Excitatory_neurons'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Vascular_endothelial_cells/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Vascular_endothelial_cells/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Vascular_endothelial_cells'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Astrocytes_Oligodendrocytes'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/original_modisco/domcke_2020.fetal_brain.Cerebrum_Unknown_3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/domcke_2020/all_data_all_patterns/leiden_96/domcke_2020.fetal_brain.Cerebrum_Unknown_3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'domcke_2020.fetal_brain.Cerebrum_Unknown_3'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster9/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster9/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster9'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster4/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster4/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster4'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster10/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster10/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster10'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster20/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster20/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster20'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster22/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster22/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster22'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster8/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster8/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster8'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster7/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster7/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster7'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster19/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster19/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster19'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster15/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster15/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster15'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster13/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster13/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster13'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster5/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster5/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster5'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster18/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster18/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster18'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster21/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster21/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster21'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster16/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster16/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster16'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster14/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster14/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster14'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster3/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster3'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster6/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster6/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster6'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster12/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster12/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster12'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster1/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster1/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster1'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster2/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster2/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster2'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster23/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster23/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster23'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster17/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster17/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster17'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster11/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster11/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster11'),
#  ('/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/original_modisco/corces_2020.Cluster24/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   '/oak/stanford/groups/akundaje/projects/neuro-variants/finemo_variants/rare/K562_bias/corces_2020/all_data_all_patterns/leiden_96/corces_2020.Cluster24/mean/counts/alpha_0.8/variant_hit_calls.tsv',
#   'corces_2020.Cluster24')]

# %%
# Process the files in parallel
with Pool(40) as pool:
    results = pool.starmap(process_variant_motifs, [(info, original_pattern_to_cluster, merged_pattern_to_cluster) for info in file_infos])

# %%
rare_variants = pd.read_table(rare_variants_file, names=['chr_hg38', 'pos_hg38', 'allele1', 'allele2', 'variant_id'])

rare_variants
# Out:
#      chr_hg38   pos_hg38 allele1 allele2          variant_id
# 0        chr1  101816427       A       T  chr1:101816427:A:T
# 1        chr1   10646593       A       G   chr1:10646593:A:G
# 2        chr1  108559923       G       C  chr1:108559923:G:C
# 3        chr1  108609660       G       A  chr1:108609660:G:A
# 4        chr1  108746573       G       A  chr1:108746573:G:A
# ...       ...        ...     ...     ...                 ...
# 1612    chr22   44201792       C       T  chr22:44201792:C:T
# 1613    chr22   45831660       T       A  chr22:45831660:T:A
# 1614    chr22   45831848       G       C  chr22:45831848:G:C
# 1615    chr22   49827389       A       C  chr22:49827389:A:C
# 1616    chr22   50733863       C       T  chr22:50733863:C:T
#
# [1617 rows x 5 columns]

# %%
# Combine results into a single DataFrame
variant_motifs = rare_variants.copy()
variant_motifs.rename(columns={'allele1': 'ref_allele', 'allele2': 'alt_allele'}, inplace=True)

for collapsed in results:
    variant_motifs = variant_motifs.merge(collapsed, on=['chr_hg38', 'pos_hg38'], how='left')

# %%
variant_motifs
# Out:
#      chr_hg38   pos_hg38 ref_allele alt_allele          variant_id  \
# 0        chr1  101816427          A          T  chr1:101816427:A:T
# 1        chr1   10646593          A          G   chr1:10646593:A:G
# 2        chr1  108559923          G          C  chr1:108559923:G:C
# 3        chr1  108609660          G          A  chr1:108609660:G:A
# 4        chr1  108746573          G          A  chr1:108746573:G:A
# ...       ...        ...        ...        ...                 ...
# 1612    chr22   44201792          C          T  chr22:44201792:C:T
# 1613    chr22   45831660          T          A  chr22:45831660:T:A
# 1614    chr22   45831848          G          C  chr22:45831848:G:C
# 1615    chr22   49827389          A          C  chr22:49827389:A:C
# 1616    chr22   50733863          C          T  chr22:50733863:C:T
#
#      trevino_2021.c20.ref_allele_motifs trevino_2021.c20.alt_allele_motifs  \
# 0                                   NaN                                NaN
# 1                              ZNF143_1                           ZNF143_1
# 2                                 ATF_1                                NaN
# 3                                   NaN                                NaN
# 4                       SP-KLF_1, ETS_2                                NaN
# ...                                 ...                                ...
# 1612                                NaN                                NaN
# 1613                                NaN                                NaN
# 1614                                NaN                                NaN
# 1615                                YY1                                NaN
# 1616                                NaN                                NaN
#
#      trevino_2021.c20.all_motifs trevino_2021.c19.ref_allele_motifs  \
# 0                            NaN                                NaN
# 1              ZNF143_1,ZNF143_1                           ZNF143_1
# 2                          ATF_1                              ATF_1
# 3                            NaN                              ETS_1
# 4                SP-KLF_1, ETS_2                              ETS_2
# ...                          ...                                ...
# 1612                         NaN                                NaN
# 1613                         NaN                                NaN
# 1614                         NaN                                NaN
# 1615                         YY1                                YY1
# 1616                         NaN                                NaN
#
#      trevino_2021.c19.alt_allele_motifs  ... corces_2020.Cluster23.all_motifs  \
# 0                                   NaN  ...                              NaN
# 1                              ZNF143_1  ...                ZNF143_1,ZNF143_1
# 2                              SP-KLF_1  ...                         ZEB-SNAI
# 3                                 ETS_1  ...                              NaN
# 4                                   NaN  ...                         SP-KLF_1
# ...                                 ...  ...                              ...
# 1612                                NaN  ...                         ZEB-SNAI
# 1613                                NaN  ...                              NaN
# 1614                                NaN  ...                              NaN
# 1615                                NaN  ...                              NaN
# 1616                                NaN  ...                              NaN
#
#      corces_2020.Cluster17.ref_allele_motifs  \
# 0                                        NaN
# 1                                   ZNF143_1
# 2                                        NaN
# 3                                        NaN
# 4                                   SP-KLF_1
# ...                                      ...
# 1612                                     NaN
# 1613                                     NaN
# 1614                                     NaN
# 1615                                     NaN
# 1616                                     NaN
#
#      corces_2020.Cluster17.alt_allele_motifs corces_2020.Cluster17.all_motifs  \
# 0                                        NaN                              NaN
# 1                                        NaN                         ZNF143_1
# 2                                        NaN                              NaN
# 3                                        NaN                              NaN
# 4                                        NaN                         SP-KLF_1
# ...                                      ...                              ...
# 1612                                     NaN                              NaN
# 1613                                     NaN                              NaN
# 1614                                     NaN                              NaN
# 1615                                     NaN                              NaN
# 1616                                     NaN                              NaN
#
#      corces_2020.Cluster11.ref_allele_motifs  \
# 0                                        NaN
# 1                                   ZNF143_1
# 2                                      ATF_1
# 3                                        NaN
# 4                            ETS_2, SP-KLF_1
# ...                                      ...
# 1612                                     NaN
# 1613                                     NaN
# 1614                                     NaN
# 1615                                     YY1
# 1616                                     NaN
#
#      corces_2020.Cluster11.alt_allele_motifs corces_2020.Cluster11.all_motifs  \
# 0                                        NaN                              NaN
# 1                                        NaN                         ZNF143_1
# 2                                        NaN                            ATF_1
# 3                                        NaN                              NaN
# 4                                        NaN                  ETS_2, SP-KLF_1
# ...                                      ...                              ...
# 1612                                ZEB-SNAI                         ZEB-SNAI
# 1613                                TEF, TEF                         TEF, TEF
# 1614                                     NaN                              NaN
# 1615                                     NaN                              YY1
# 1616                                     NaN                              NaN
#
#      corces_2020.Cluster24.ref_allele_motifs  \
# 0                                        NaN
# 1                                   ZNF143_1
# 2                                      ATF_1
# 3                                        NaN
# 4                                      ETS_2
# ...                                      ...
# 1612                                     NaN
# 1613                                     NaN
# 1614                                     NaN
# 1615                                     YY1
# 1616                                     NaN
#
#      corces_2020.Cluster24.alt_allele_motifs corces_2020.Cluster24.all_motifs
# 0                                        NaN                              NaN
# 1                                   ZNF143_2                ZNF143_1,ZNF143_2
# 2                                   SP-KLF_1                   ATF_1,SP-KLF_1
# 3                                        NaN                              NaN
# 4                                        NaN                            ETS_2
# ...                                      ...                              ...
# 1612                                ZEB-SNAI                         ZEB-SNAI
# 1613                                     NaN                              NaN
# 1614                                     NaN                              NaN
# 1615                                     NaN                              YY1
# 1616                                     NaN                              NaN
#
# [1617 rows x 167 columns]

# %%
variant_motifs.to_csv(table_dir + '/rare_variants.motif_annotations.all_data_all_patterns.' + leiden + '.' + alpha + '.tsv',
                      sep='\t', index=False)

# %%
excitatory_neuron_clusters = ['corces_2020.Cluster1', 'corces_2020.Cluster3', 'corces_2020.Cluster4',
                                'trevino_2021.c0', 'trevino_2021.c1', 'trevino_2021.c2',
                                'trevino_2021.c5', 'trevino_2021.c6', 'trevino_2021.c7',
                                'trevino_2021.c13', 'trevino_2021.c14', 'trevino_2021.c18',
                                'domcke_2020.fetal_brain.Excitatory_neurons']

all_variants = variant_motifs['variant_id'].unique()

# Dictionary to store the final binary matrices for each cell type
binary_matrices = {}

for cluster in excitatory_neuron_clusters:
    col_name = f"{cluster}.all_motifs"
    
    # If the column doesn't exist in df, skip or handle accordingly
    if col_name not in variant_motifs.columns:
        continue
    
    # 1) Subset to variant_id and the cluster's motif column
    sub_df = variant_motifs[['variant_id', col_name]].copy()
    
    # 2) Split on commas and explode
    sub_df[col_name] = sub_df[col_name].fillna('').str.split(',')
    sub_df = sub_df.explode(col_name)
    sub_df[col_name] = sub_df[col_name].str.strip()
    
    # 3) Remove any empty entries (which can appear if the cell was NaN)
    sub_df = sub_df[sub_df[col_name] != '']
    
    # 4) Pivot to create a binary matrix
    #    Assign an indicator column "ind=1" for presence
    binary_matrix = (
        sub_df
        .assign(ind=1)
        .pivot_table(index='variant_id', 
                     columns=col_name, 
                     values='ind', 
                     fill_value=0)
    )
    
    binary_matrix = binary_matrix.reindex(all_variants, fill_value=0)
    binary_matrix.index.name = None
    binary_matrix.columns.name = None

    # Store in the dictionary
    binary_matrices[cluster] = binary_matrix

# Find union of columns across all binary matrices
all_motifs = set()
for mat in binary_matrices.values():
    all_motifs |= set(mat.columns)

all_motifs = sorted(all_motifs)

# Reindex each DataFrame so they share the same motif columns
for cluster, mat in binary_matrices.items():
    binary_matrices[cluster] = mat.reindex(columns=all_motifs, fill_value=0)
    binary_matrices[cluster]

for dataset in ['corces_2020', 'trevino_2021', 'domcke_2020']: #, 'ameen_2022', 'encode_2024']:
    os.makedirs(variant_motif_matrices_dir + '/all_data_all_patterns/' + leiden + '/' + alpha + '/' + dataset, exist_ok=True)
    for cluster in [i for i in binary_matrices if i.startswith(dataset)]:
        binary_matrices[cluster].to_csv(variant_motif_matrices_dir + '/all_data_all_patterns/' + leiden + '/' + alpha + '/' + dataset + '/' + cluster + '.tsv',
                                        sep='\t')

# %%
binary_matrices['corces_2020.Cluster1']['NDF-ATOH_1'].sum()
# Out:
# 64.0

# %%
binary_matrices['trevino_2021.c0']['NDF-ATOH_1'].sum()
# Out:
# 158.0

# %%
binary_matrices['domcke_2020.fetal_brain.Excitatory_neurons']['NDF-ATOH_1'].sum()
# Out:
# 160.0
